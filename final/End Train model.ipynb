# %% [markdown]
# <a href="https://colab.research.google.com/github/cjfghk5697/multi-label-classification-Mnist/blob/main/End%20Train%20model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. 이진화 코드 추가
#  이진화란 이미지를 흰색과 검은색으로 바꾼다고 생각하면 된다.
# 속도가 향상되고 정확도도 미약하지만 향상된것을 볼수 있다.
#
#  [Dacon 적용 예시](https://dacon.io/competitions/official/235697/codeshare/2436?page=2&dtype=recent)
#
#
#  [이진화 설명](https://gmnam.tistory.com/263)
#
#  <hr>
#
#  # 2. train, valid set 나누기
# ```
# train_dataset, valid_dataset = torch.utils.data.random_split(trainset, [train_size, valid_size])
#
# train_loader = DataLoader(train_dataset, batch_size=64, num_workers=8)
# valid_loader = DataLoader(valid_dataset, batch_size=64, num_workers=8)
# ```
# 처음에는 나누어지지 않아있는 코드였단 걸 발견하고 random_split 함수를 이용해 나눔. 그리고 학습 부분에서 valid 데이터를 enumerate하는 구문추가해서 valid 확인.
#
# <hr>
#
# # 3. Multi Sample Dropout 구현
#
# [자료](https://velog.io/@sujeongim/%EC%83%88%EB%A1%9C-%EB%B0%B0%EC%9A%B4-%EC%BD%94%EB%93%9C-%EC%A1%B0%EA%B0%81-Multi-Sample-Dropout)
# 단순 dropout 기법을 안썼다. 근데 큰효과가 있는지는 잘 모르지만 overfitting의 위협도 없앨겸 선택했다.
#
# <hr>
#
# # 4. Scheduler 추가
# 일단 간단하게 StepLR scheduler을 추가했다.
#
#
#
# <hr>
#
# # 5. Drop out 실수
# 전 Drop out에서는 sigmoid가 있다. 근데 필자가 Multi-Label Loss Function을 이용함으로써 활성화 함수를 더 추가할 필요가 없었다. 그러나 sigmoid를 또 넣음으로써 sigmoid 계층 2개를 들어가는 거다. 결국 loss 값이 적어져서 학습 진행이 안된거다. 학습이 잘 안되면 활성화 함수에서 loss 값이 얼마 나오는지 잘 확인해야겠다..
#
# https://cvml.tistory.com/26
# Multi-Label Loss Function에 대해 잘 설명 되어있다.
#
#
# <hr>
#
# # 6. 왜 정확도가 안오를까?
# 이상하게도 valid도 장확도가 같이 오르는데 test를 하면 정확도는 50%다 혹시나 해서 이진화를 빼고 해봤는데도 정확도가 안오른다 (05.15)
#
# -테스트
#
# 1. efficientnetb1에서 epoch 수를 늘려봤다. 과거에는 5번 정도만 해도 valid 정확도가 높게 나왔다. 하지만 epoch를 늘린다고 해결될 일이 절대 아닌 거 같다.
#
# 2. overfitting 인거 같아서 dropout을 추가했다. 활성화 함수도 한층 추가해봐서 실험. (실패)
#
# 3. 추적그래프를 그리기 위해 추적그래프를 추가했다.
#
# 4. DACON 토론에 올렸다.[링크](https://dacon.io/forum/406352)  답변이 왔고 확실히 여기서 model.eval()과 model.train(), model.zero_grab()에 대해 다시 공부했다.. valid에 zero_grab을 하여 학습이 진행되고 있었고 eval 또한 안해서 불필요한 과정을 가지고 있었다.
#
# ### 해결
# 결국은 inference에서 모델을 잘못 가지고 오고 있었다.. 결국 다시해본결과 80% 정확도가 나왔지만 아직 90% 정확도는 안나온다.
#
# # 7. 또다시 연구
# 이번에는 적절한 파라미터를 찾기위한 튜닝 작업을 해보고자 한다.
#
# 일단 Train 코드에서는 augmentation(mix up
# )과 여러 scheduler를 추가하려고한다. 이제 휴가가 끝나서 시간 날때마다 추가해야겠다.
#
# # 8. 최종, 마무리 (2022-06-18)
# 마지막으로 TTA+ensemble 기법을 추가하였다. 그냥 간단히 학습시킨 모델임에도 좋은 결과를 냈다. 이제부터는 자연어처리 공부를 시작할 거다.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Train image2
# !unzip -q "/content/drive/MyDrive/multi-mnist zipfile/dirty_mnist_2nd.zip"
# Out:
# /content/drive/MyDrive/Train image2

# %%
# !pip3 install torchinfo
# !pip3 install cv2
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torchinfo
#   Downloading torchinfo-1.7.0-py3-none-any.whl (22 kB)
# Installing collected packages: torchinfo
# Successfully installed torchinfo-1.7.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ERROR: Could not find a version that satisfies the requirement cv2 (from versions: none)
# ERROR: No matching distribution found for cv2

# %%
import os
from typing import Tuple, Sequence, Callable
import csv
import cv2
import numpy as np
import pandas as pd
from PIL import Image
import torch
import torch.optim as optim
from torch import nn, Tensor
from torch.utils.data import Dataset, DataLoader
from torchinfo import summary
from torchvision import transforms
from torchvision.models import efficientnet_b5
from torch.nn import functional as F
from torch.autograd import Variable

# %%
class MnistDataset(Dataset):
    def __init__(
        self,
        dir: os.PathLike,
        image_ids: os.PathLike,
        transforms: Sequence[Callable]
    ) -> None:
        self.dir = dir
        self.transforms = transforms

        self.labels = {}
        with open(image_ids, 'r') as f:
            reader = csv.reader(f)
            next(reader)
            for row in reader:
                self.labels[int(row[0])] = list(map(int, row[1:]))

        self.image_ids = list(self.labels.keys())

    def __len__(self) -> int:
        return len(self.image_ids)

    def __getitem__(self, index: int) -> Tuple[Tensor]:
        image_id = self.image_ids[index]
        image = Image.open(
            os.path.join(
                self.dir, f'{str(image_id).zfill(5)}.png')).convert('RGB')
        target = np.array(self.labels.get(image_id)).astype(np.float32)


        #image = np.array(image)
#이진화 완료 cv2 툴을 써서 threshold로 254 값으로 변환. cv2는 넘파이만 사용 가능해서 넘파이로 변환후 fromarry로 pil로 바꾼다.
        #image_th = cv2.threshold(image,254,255,0)[1]
        #image_th = Image.fromarray(image_th) # NumPy array to PIL image
        if self.transforms is not None:
            image = self.transforms(image)

        return image, target

# %%
transforms_train = transforms.Compose([
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomVerticalFlip(p=0.5),
    transforms.ToTensor(),
    transforms.Normalize(
        [0.485, 0.456, 0.406],
        [0.229, 0.224, 0.225]
    )
])

transforms_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(
        [0.485, 0.456, 0.406],
        [0.229, 0.224, 0.225]
    )
])

# %%
trainset = MnistDataset('/content/drive/MyDrive/Train image2', '/content/drive/MyDrive/multi-mnist zipfile/dirty_mnist_2nd_answer.csv', transforms_train)

lengths = [int(len(trainset)*0.8), int(len(trainset)*0.2)]

train_dataset, valid_dataset = torch.utils.data.random_split(trainset, lengths)

train_loader = DataLoader(train_dataset, batch_size=16, num_workers=2)
valid_loader = DataLoader(valid_dataset, batch_size=8, num_workers=2)

# %%
class MnistModel(nn.Module):
    def __init__(self) -> None:
        super().__init__()
        self.model = efficientnet_b5(pretrained=True)
        self.dropout=nn.Dropout(p=0.2)
        self.classifier = nn.Linear(1000, 26)
        self.SiLU=nn.SiLU(inplace=False)
        self.GELU=nn.GELU()
    def forward(self, x):
        #x = F.relu(self.model(x))
        x = self.model(x) 
        x = self.dropout(x)
        x = self.SiLU(x) 
        x = self.classifier(x)
        return x

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = MnistModel().to(device)
print(summary(model, input_size=(1, 3, 256, 256), verbose=0))
# Out:
# Downloading: "https://download.pytorch.org/models/efficientnet_b5_lukemelas-b6417697.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_b5_lukemelas-b6417697.pth
#   0%|          | 0.00/117M [00:00<?, ?B/s]
# ==============================================================================================================
# Layer (type:depth-idx)                                       Output Shape              Param #
# ==============================================================================================================
# MnistModel                                                   [1, 26]                   --
# ├─EfficientNet: 1-1                                          [1, 1000]                 --
# │    └─Sequential: 2-1                                       [1, 2048, 8, 8]           --
# │    │    └─ConvNormActivation: 3-1                          [1, 48, 128, 128]         1,392
# │    │    └─Sequential: 3-2                                  [1, 24, 128, 128]         5,352
# │    │    └─Sequential: 3-3                                  [1, 40, 64, 64]           122,846
# │    │    └─Sequential: 3-4                                  [1, 64, 32, 32]           329,514
# │    │    └─Sequential: 3-5                                  [1, 128, 16, 16]          1,632,464
# │    │    └─Sequential: 3-6                                  [1, 176, 16, 16]          3,286,344
# │    │    └─Sequential: 3-7                                  [1, 304, 8, 8]            12,165,292
# │    │    └─Sequential: 3-8                                  [1, 512, 8, 8]            9,744,908
# │    │    └─ConvNormActivation: 3-9                          [1, 2048, 8, 8]           1,052,672
# │    └─AdaptiveAvgPool2d: 2-2                                [1, 2048, 1, 1]           --
# │    └─Sequential: 2-3                                       [1, 1000]                 --
# │    │    └─Dropout: 3-10                                    [1, 2048]                 --
# │    │    └─Linear: 3-11                                     [1, 1000]                 2,049,000
# ├─Dropout: 1-2                                               [1, 1000]                 --
# ├─SiLU: 1-5                                                  [1, 1000]                 --
# ├─Linear: 1-4                                                [1, 26]                   26,026
# ├─SiLU: 1-5                                                  [1, 1000]                 --
# ├─GELU: 1-6                                                  --                        --
# ==============================================================================================================
# Total params: 30,415,810
# Trainable params: 30,415,810
# Non-trainable params: 0
# Total mult-adds (G): 3.08
# ==============================================================================================================
# Input size (MB): 0.79
# Forward/backward pass size (MB): 488.92
# Params size (MB): 121.66
# Estimated Total Size (MB): 611.37
# ==============================================================================================================

# %%
def mixup_data(x, y, alpha=1.0, use_cuda=True):
    '''Returns mixed inputs, pairs of targets, and lambda'''
    if alpha > 0:
        lam = np.random.beta(alpha, alpha)
    else:
        lam = 1

    batch_size = x.size()[0]
    if use_cuda:
        index = torch.randperm(batch_size).cuda()
    else:
        index = torch.randperm(batch_size)

    mixed_x = lam * x + (1 - lam) * x[index, :]
    y_a, y_b = y, y[index]
    return mixed_x, y_a, y_b, lam


def mixup_criterion(criterion, pred, y_a, y_b, lam):
    return lam * criterion(pred, y_a) + (1 - lam) * criterion(pred, y_b)

# %%
    #scheduler 추가 및 step 추가
path = "/content/drive/MyDrive/models/"
MODEL = "06018 eff5"
base_optimizer = torch.optim.SGD 
optimizer = optim.AdamW(model.parameters(), lr=1e-3)

num_epochs = 50
lr_scheduler = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(optimizer, T_0=10, T_mult=1, eta_min=0.001, last_epoch=-1)
criterion = nn.MultiLabelSoftMarginLoss()

valid_loss_list=[]
train_loss_list=[]
for epoch in range(num_epochs):
    train_acc_list = []
    valid_acc_list =[]
    model.train()
    for i, (images, targets) in enumerate(train_loader):
        optimizer.zero_grad()

        images = images.to(device)
        targets = targets.to(device)

        images, targets_a, targets_b, lam = mixup_data(images, targets)
        images, targets_a, targets_b = map(Variable, (images, targets_a, targets_b))

        outputs = model(images)
        loss = mixup_criterion(criterion, outputs, targets_a, targets_b, lam)

        loss.backward()
        optimizer.step()

        if (i+1) % 10 == 0:
            outputs = outputs > 0.5
            acc = (outputs == targets).cpu().float().mean()
            train_acc_list.append(acc)
            train_loss_list.append(loss)
            print(f'{epoch}: "train loss:"{loss.item():.5f}, "train acc: "{acc.item():.5f}')
    model.eval()
    with torch.no_grad():
      for i, (images, targets) in enumerate(valid_loader):

          images = images.to(device)
          targets = targets.to(device)

          outputs = model(images)
          valid_loss = criterion(outputs, targets)
      
          if (i+1) % 10 == 0:
              outputs = outputs > 0.5
              valid_acc = (outputs == targets).cpu().float().mean()
              valid_acc_list.append(valid_acc)
              valid_loss_list.append(valid_loss)
              print(f'{epoch}: "val loss:"{valid_loss.item():.5f}, "val acc: "{valid_acc.item():.5f}')
    lr_scheduler.step()
    torch.save(model.state_dict(), f'{path}_{MODEL}_1.pth')
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# 10: "train loss:"0.67982, "train acc: "0.58413
# 10: "train loss:"0.58675, "train acc: "0.74279
# 10: "train loss:"0.51992, "train acc: "0.76442
# 10: "train loss:"0.58148, "train acc: "0.73558
# 10: "train loss:"0.46478, "train acc: "0.79087
# 10: "train loss:"0.66380, "train acc: "0.52404
# 10: "train loss:"0.56470, "train acc: "0.74519
# 10: "train loss:"0.47458, "train acc: "0.78846
# 10: "train loss:"0.50069, "train acc: "0.80048
# 10: "train loss:"0.65257, "train acc: "0.55769
# 10: "train loss:"0.58671, "train acc: "0.52404
# 10: "train loss:"0.60052, "train acc: "0.53125
# 10: "train loss:"0.66317, "train acc: "0.54327
# 10: "train loss:"0.61968, "train acc: "0.59135
# 10: "train loss:"0.48124, "train acc: "0.80769
# 10: "train loss:"0.49740, "train acc: "0.80769
# 10: "train loss:"0.54049, "train acc: "0.74519
# 10: "train loss:"0.68359, "train acc: "0.55048
# 10: "train loss:"0.64945, "train acc: "0.51923
# 10: "train loss:"0.59112, "train acc: "0.74279
# 10: "train loss:"0.55190, "train acc: "0.48077
# 10: "train loss:"0.66219, "train acc: "0.61538
# 10: "train loss:"0.63963, "train acc: "0.47356
# 10: "train loss:"0.51853, "train acc: "0.45673
# 10: "train loss:"0.50658, "train acc: "0.46875
# 10: "train loss:"0.46998, "train acc: "0.77163
# 10: "train loss:"0.65684, "train acc: "0.58413
# 10: "train loss:"0.47524, "train acc: "0.49760
# 10: "train loss:"0.62800, "train acc: "0.70673
# 10: "train loss:"0.64230, "train acc: "0.55048
# 10: "train loss:"0.56894, "train acc: "0.72356
# 10: "train loss:"0.62057, "train acc: "0.62740
# 10: "train loss:"0.63834, "train acc: "0.58894
# 10: "train loss:"0.63395, "train acc: "0.57933
# 10: "train loss:"0.47250, "train acc: "0.77163
# 10: "train loss:"0.67292, "train acc: "0.62260
# 10: "train loss:"0.56726, "train acc: "0.53606
# 10: "train loss:"0.60940, "train acc: "0.53846
# 10: "train loss:"0.55669, "train acc: "0.73077
# 10: "train loss:"0.62846, "train acc: "0.55048
# 10: "train loss:"0.55283, "train acc: "0.52885
# 10: "train loss:"0.66076, "train acc: "0.53846
# 10: "train loss:"0.52441, "train acc: "0.73798
# 10: "train loss:"0.64112, "train acc: "0.61058
# 10: "train loss:"0.55391, "train acc: "0.48317
# 10: "train loss:"0.66019, "train acc: "0.60337
# 10: "train loss:"0.52871, "train acc: "0.52885
# 10: "train loss:"0.53631, "train acc: "0.49038
# 10: "train loss:"0.63075, "train acc: "0.64904
# 10: "train loss:"0.57545, "train acc: "0.56731
# 10: "train loss:"0.46462, "train acc: "0.78125
# 10: "train loss:"0.56803, "train acc: "0.52404
# 10: "train loss:"0.52064, "train acc: "0.55048
# 10: "train loss:"0.50023, "train acc: "0.76442
# 10: "train loss:"0.56040, "train acc: "0.50962
# 10: "train loss:"0.48862, "train acc: "0.80529
# 10: "train loss:"0.59557, "train acc: "0.66827
# 10: "train loss:"0.64107, "train acc: "0.52163
# 10: "train loss:"0.63651, "train acc: "0.58173
# 10: "train loss:"0.49071, "train acc: "0.49519
# 10: "train loss:"0.60119, "train acc: "0.56731
# 10: "train loss:"0.62070, "train acc: "0.58413
# 10: "train loss:"0.61839, "train acc: "0.69471
# 10: "train loss:"0.55517, "train acc: "0.58173
# 10: "train loss:"0.38619, "train acc: "0.45192
# 10: "train loss:"0.51826, "train acc: "0.50240
# 10: "train loss:"0.58790, "train acc: "0.74760
# 10: "train loss:"0.48892, "train acc: "0.77163
# 10: "train loss:"0.64558, "train acc: "0.60577
# 10: "train loss:"0.55613, "train acc: "0.75000
# 10: "train loss:"0.54139, "train acc: "0.77163
# 10: "train loss:"0.52576, "train acc: "0.56010
# 10: "train loss:"0.57369, "train acc: "0.54327
# 10: "train loss:"0.60529, "train acc: "0.50721
# 10: "train loss:"0.46842, "train acc: "0.76683
# 10: "train loss:"0.50759, "train acc: "0.77163
# 10: "train loss:"0.58346, "train acc: "0.73317
# 10: "train loss:"0.64700, "train acc: "0.66106
# 10: "train loss:"0.60313, "train acc: "0.55288
# 10: "train loss:"0.56266, "train acc: "0.55288
# 10: "train loss:"0.48549, "train acc: "0.79327
# 10: "train loss:"0.51458, "train acc: "0.58413
# 10: "train loss:"0.61388, "train acc: "0.66827
# 10: "train loss:"0.61866, "train acc: "0.68510
# 10: "train loss:"0.58268, "train acc: "0.72356
# 10: "train loss:"0.63285, "train acc: "0.68029
# 10: "train loss:"0.62685, "train acc: "0.61538
# 10: "train loss:"0.67137, "train acc: "0.56490
# 10: "train loss:"0.54183, "train acc: "0.76202
# 10: "train loss:"0.55509, "train acc: "0.74760
# 10: "train loss:"0.61405, "train acc: "0.55288
# 10: "train loss:"0.56959, "train acc: "0.78365
# 10: "train loss:"0.63022, "train acc: "0.62260
# 10: "train loss:"0.65569, "train acc: "0.55769
# 10: "train loss:"0.53524, "train acc: "0.78125
# 10: "train loss:"0.45649, "train acc: "0.77163
# 10: "train loss:"0.58020, "train acc: "0.74519
# 10: "train loss:"0.54059, "train acc: "0.52885
# 10: "train loss:"0.46181, "train acc: "0.78125
# 10: "train loss:"0.54384, "train acc: "0.49279
# 10: "train loss:"0.57016, "train acc: "0.51683
# 10: "train loss:"0.47035, "train acc: "0.77644
# 10: "train loss:"0.59311, "train acc: "0.69712
# 10: "train loss:"0.66384, "train acc: "0.53606
# 10: "train loss:"0.65446, "train acc: "0.63462
# 10: "train loss:"0.61851, "train acc: "0.61779
# 10: "train loss:"0.53458, "train acc: "0.51442
# 10: "train loss:"0.64017, "train acc: "0.48798
# 10: "train loss:"0.61629, "train acc: "0.58894
# 10: "train loss:"0.47448, "train acc: "0.80288
# 10: "train loss:"0.45317, "train acc: "0.78606
# 10: "train loss:"0.53501, "train acc: "0.74038
# 10: "train loss:"0.64586, "train acc: "0.66346
# 10: "train loss:"0.64299, "train acc: "0.57933
# 10: "train loss:"0.44050, "train acc: "0.81490
# 10: "train loss:"0.57218, "train acc: "0.74279
# 10: "train loss:"0.63754, "train acc: "0.58173
# 10: "train loss:"0.58625, "train acc: "0.74760
# 10: "train loss:"0.57987, "train acc: "0.73798
# 10: "train loss:"0.52635, "train acc: "0.47596
# 10: "train loss:"0.66223, "train acc: "0.62981
# 10: "train loss:"0.62973, "train acc: "0.51683
# 10: "train loss:"0.61994, "train acc: "0.71875
# 10: "train loss:"0.63088, "train acc: "0.68510
# 10: "train loss:"0.50005, "train acc: "0.56010
# 10: "train loss:"0.63926, "train acc: "0.68269
# 10: "train loss:"0.66072, "train acc: "0.56010
# 10: "train loss:"0.63424, "train acc: "0.52163
# 10: "train loss:"0.62976, "train acc: "0.60096
# 10: "train loss:"0.64380, "train acc: "0.60337
# 10: "train loss:"0.50469, "train acc: "0.80288
# 10: "train loss:"0.51721, "train acc: "0.57933
# 10: "train loss:"0.53058, "train acc: "0.76202
# 10: "train loss:"0.65220, "train acc: "0.54808
# 10: "train loss:"0.66022, "train acc: "0.67067
# 10: "train loss:"0.47579, "train acc: "0.75721
# 10: "train loss:"0.61209, "train acc: "0.51442
# 10: "train loss:"0.60117, "train acc: "0.58654
# 10: "train loss:"0.56445, "train acc: "0.53125
# 10: "train loss:"0.66074, "train acc: "0.58894
# 10: "train loss:"0.55070, "train acc: "0.52644
# 10: "train loss:"0.58173, "train acc: "0.47115
# 10: "train loss:"0.51486, "train acc: "0.52885
# 10: "train loss:"0.61379, "train acc: "0.68269
# 10: "train loss:"0.57358, "train acc: "0.75240
# 10: "train loss:"0.47747, "train acc: "0.52404
# 10: "train loss:"0.52175, "train acc: "0.56010
# 10: "train loss:"0.62018, "train acc: "0.67548
# 10: "train loss:"0.45084, "train acc: "0.81971
# 10: "train loss:"0.53591, "train acc: "0.76683
# 10: "train loss:"0.48785, "train acc: "0.47596
# 10: "train loss:"0.50379, "train acc: "0.77404
# 10: "train loss:"0.62009, "train acc: "0.70192
# 10: "train loss:"0.45178, "train acc: "0.82212
# 10: "train loss:"0.58232, "train acc: "0.52163
# 10: "train loss:"0.64724, "train acc: "0.66827
# 10: "train loss:"0.65356, "train acc: "0.63221
# 10: "train loss:"0.50410, "train acc: "0.80288
# 10: "train loss:"0.65047, "train acc: "0.54327
# 10: "train loss:"0.53936, "train acc: "0.78846
# 10: "train loss:"0.64910, "train acc: "0.55048
# 10: "train loss:"0.59241, "train acc: "0.51683
# 10: "train loss:"0.63261, "train acc: "0.58654
# 10: "train loss:"0.63719, "train acc: "0.56971
# 10: "train loss:"0.48350, "train acc: "0.76923
# 10: "train loss:"0.53783, "train acc: "0.56250
# 10: "val loss:"0.44574, "val acc: "0.76442
# 10: "val loss:"0.43252, "val acc: "0.76923
# 10: "val loss:"0.58914, "val acc: "0.67308
# 10: "val loss:"0.44313, "val acc: "0.77404
# 10: "val loss:"0.48013, "val acc: "0.75962
# 10: "val loss:"0.52952, "val acc: "0.74519
# 10: "val loss:"0.44812, "val acc: "0.79808
# 10: "val loss:"0.44536, "val acc: "0.75481
# 10: "val loss:"0.45848, "val acc: "0.76923
# 10: "val loss:"0.53640, "val acc: "0.69712
# 10: "val loss:"0.47145, "val acc: "0.75962
# 10: "val loss:"0.44708, "val acc: "0.75481
# 10: "val loss:"0.42698, "val acc: "0.77885
# 10: "val loss:"0.52438, "val acc: "0.70192
# 10: "val loss:"0.53719, "val acc: "0.76442
# 10: "val loss:"0.54006, "val acc: "0.74519
# 10: "val loss:"0.41890, "val acc: "0.78846
# 10: "val loss:"0.37927, "val acc: "0.81731
# 10: "val loss:"0.50713, "val acc: "0.77885
# 10: "val loss:"0.47776, "val acc: "0.75962
# 10: "val loss:"0.43977, "val acc: "0.75962
# 10: "val loss:"0.48041, "val acc: "0.77404
# 10: "val loss:"0.51261, "val acc: "0.73077
# 10: "val loss:"0.44110, "val acc: "0.76923
# 10: "val loss:"0.50022, "val acc: "0.76442
# 10: "val loss:"0.42194, "val acc: "0.78846
# 10: "val loss:"0.44578, "val acc: "0.79808
# 10: "val loss:"0.47379, "val acc: "0.77885
# 10: "val loss:"0.51135, "val acc: "0.73077
# 10: "val loss:"0.48265, "val acc: "0.76442
# 10: "val loss:"0.57041, "val acc: "0.72596
# 10: "val loss:"0.56682, "val acc: "0.72596
# 10: "val loss:"0.44993, "val acc: "0.80288
# 10: "val loss:"0.50132, "val acc: "0.74519
# 10: "val loss:"0.43983, "val acc: "0.77885
# 10: "val loss:"0.47629, "val acc: "0.75962
# 10: "val loss:"0.49828, "val acc: "0.76923
# 10: "val loss:"0.42853, "val acc: "0.77885
# 10: "val loss:"0.39570, "val acc: "0.81731
# 10: "val loss:"0.45395, "val acc: "0.75962
# 10: "val loss:"0.43989, "val acc: "0.79327
# 10: "val loss:"0.44070, "val acc: "0.78846
# 10: "val loss:"0.48292, "val acc: "0.76923
# 10: "val loss:"0.45562, "val acc: "0.79808
# 10: "val loss:"0.43244, "val acc: "0.79808
# 10: "val loss:"0.45596, "val acc: "0.78365
# 10: "val loss:"0.51821, "val acc: "0.75962
# 10: "val loss:"0.47205, "val acc: "0.75000
# 10: "val loss:"0.44853, "val acc: "0.77404
# 10: "val loss:"0.58492, "val acc: "0.67788
# 10: "val loss:"0.46822, "val acc: "0.75962
# 10: "val loss:"0.44018, "val acc: "0.77885
# 10: "val loss:"0.48198, "val acc: "0.77885
# 10: "val loss:"0.48649, "val acc: "0.77885
# 10: "val loss:"0.43530, "val acc: "0.77885
# 10: "val loss:"0.44879, "val acc: "0.79327
# 10: "val loss:"0.42981, "val acc: "0.76442
# 10: "val loss:"0.41473, "val acc: "0.77404
# 10: "val loss:"0.43030, "val acc: "0.78365
# 10: "val loss:"0.46769, "val acc: "0.76442
# 10: "val loss:"0.40139, "val acc: "0.81250
# 10: "val loss:"0.54522, "val acc: "0.71635
# 10: "val loss:"0.49379, "val acc: "0.73558
# 10: "val loss:"0.43422, "val acc: "0.75962
# 10: "val loss:"0.44536, "val acc: "0.76923
# 10: "val loss:"0.42748, "val acc: "0.80288
# 10: "val loss:"0.55341, "val acc: "0.73077
# 10: "val loss:"0.43659, "val acc: "0.78846
# 10: "val loss:"0.44108, "val acc: "0.75000
# 10: "val loss:"0.43800, "val acc: "0.77404
# 10: "val loss:"0.53626, "val acc: "0.72596
# 10: "val loss:"0.52567, "val acc: "0.70673
# 10: "val loss:"0.50385, "val acc: "0.75000
# 10: "val loss:"0.46641, "val acc: "0.76923
# 10: "val loss:"0.41930, "val acc: "0.76442
# 10: "val loss:"0.47357, "val acc: "0.74038
# 10: "val loss:"0.44918, "val acc: "0.81731
# 10: "val loss:"0.51691, "val acc: "0.72596
# 10: "val loss:"0.39382, "val acc: "0.80288
# 10: "val loss:"0.49664, "val acc: "0.75481
# 10: "val loss:"0.45141, "val acc: "0.79808
# 10: "val loss:"0.51170, "val acc: "0.73077
# 10: "val loss:"0.53311, "val acc: "0.73077
# 10: "val loss:"0.46600, "val acc: "0.74519
# 10: "val loss:"0.49156, "val acc: "0.72115
# 10: "val loss:"0.36335, "val acc: "0.80769
# 10: "val loss:"0.49347, "val acc: "0.75000
# 10: "val loss:"0.40233, "val acc: "0.81731
# 10: "val loss:"0.46068, "val acc: "0.77885
# 10: "val loss:"0.41196, "val acc: "0.81250
# 10: "val loss:"0.49174, "val acc: "0.74038
# 10: "val loss:"0.41956, "val acc: "0.79327
# 10: "val loss:"0.42908, "val acc: "0.81731
# 10: "val loss:"0.52653, "val acc: "0.71154
# 10: "val loss:"0.48587, "val acc: "0.76923
# 10: "val loss:"0.43070, "val acc: "0.77885
# 10: "val loss:"0.41661, "val acc: "0.80288
# 10: "val loss:"0.45462, "val acc: "0.77404
# 10: "val loss:"0.46215, "val acc: "0.79327
# 10: "val loss:"0.40384, "val acc: "0.79327
# 10: "val loss:"0.45473, "val acc: "0.77404
# 10: "val loss:"0.45155, "val acc: "0.78365
# 10: "val loss:"0.46853, "val acc: "0.76923
# 10: "val loss:"0.52581, "val acc: "0.76923
# 10: "val loss:"0.48189, "val acc: "0.77885
# 10: "val loss:"0.44916, "val acc: "0.82212
# 10: "val loss:"0.46406, "val acc: "0.74519
# 10: "val loss:"0.40733, "val acc: "0.80288
# 10: "val loss:"0.43561, "val acc: "0.79808
# 10: "val loss:"0.47342, "val acc: "0.75000
# 10: "val loss:"0.41917, "val acc: "0.75481
# 10: "val loss:"0.47837, "val acc: "0.75962
# 10: "val loss:"0.43892, "val acc: "0.76442
# 10: "val loss:"0.51036, "val acc: "0.73558
# 10: "val loss:"0.46349, "val acc: "0.75481
# 10: "val loss:"0.48912, "val acc: "0.75481
# 10: "val loss:"0.42619, "val acc: "0.80769
# 10: "val loss:"0.45509, "val acc: "0.79327
# 10: "val loss:"0.43035, "val acc: "0.78365
# 10: "val loss:"0.48863, "val acc: "0.75962
# 10: "val loss:"0.45068, "val acc: "0.77404
# 10: "val loss:"0.49593, "val acc: "0.72596
# 10: "val loss:"0.45196, "val acc: "0.77404
# 10: "val loss:"0.46023, "val acc: "0.75962
# 10: "val loss:"0.45905, "val acc: "0.77404
# 11: "train loss:"0.52903, "train acc: "0.79808
# 11: "train loss:"0.60993, "train acc: "0.55288
# 11: "train loss:"0.52509, "train acc: "0.80288
# 11: "train loss:"0.61151, "train acc: "0.54567
# 11: "train loss:"0.46047, "train acc: "0.53125
# 11: "train loss:"0.59488, "train acc: "0.52404
# 11: "train loss:"0.56459, "train acc: "0.77404
# 11: "train loss:"0.53213, "train acc: "0.79808
# 11: "train loss:"0.47662, "train acc: "0.50240
# 11: "train loss:"0.54899, "train acc: "0.76442
# 11: "train loss:"0.63974, "train acc: "0.65625
# 11: "train loss:"0.65712, "train acc: "0.60096
# 11: "train loss:"0.59297, "train acc: "0.69712
# 11: "train loss:"0.60496, "train acc: "0.71875
# 11: "train loss:"0.64344, "train acc: "0.55769
# 11: "train loss:"0.41623, "train acc: "0.81010
# 11: "train loss:"0.43691, "train acc: "0.83413
# 11: "train loss:"0.62274, "train acc: "0.70192
# 11: "train loss:"0.64135, "train acc: "0.64904
# 11: "train loss:"0.64037, "train acc: "0.63221
# 11: "train loss:"0.57532, "train acc: "0.75481
# 11: "train loss:"0.47383, "train acc: "0.78365
# 11: "train loss:"0.49210, "train acc: "0.49279
# 11: "train loss:"0.66221, "train acc: "0.57212
# 11: "train loss:"0.58729, "train acc: "0.74760
# 11: "train loss:"0.66316, "train acc: "0.61298
# 11: "train loss:"0.47121, "train acc: "0.54808
# 11: "train loss:"0.54293, "train acc: "0.77404
# 11: "train loss:"0.65076, "train acc: "0.51683
# 11: "train loss:"0.64638, "train acc: "0.68990
# 11: "train loss:"0.57115, "train acc: "0.76442
# 11: "train loss:"0.63189, "train acc: "0.56010
# 11: "train loss:"0.61790, "train acc: "0.63942
# 11: "train loss:"0.56659, "train acc: "0.50481
# 11: "train loss:"0.62323, "train acc: "0.53365
# 11: "train loss:"0.53479, "train acc: "0.76442
# 11: "train loss:"0.56103, "train acc: "0.74279
# 11: "train loss:"0.53370, "train acc: "0.76683
# 11: "train loss:"0.61923, "train acc: "0.72837
# 11: "train loss:"0.63562, "train acc: "0.60096
# 11: "train loss:"0.51663, "train acc: "0.77404
# 11: "train loss:"0.56366, "train acc: "0.78846
# 11: "train loss:"0.40273, "train acc: "0.80048
# 11: "train loss:"0.55904, "train acc: "0.46875
# 11: "train loss:"0.50588, "train acc: "0.53125
# 11: "train loss:"0.42117, "train acc: "0.83654
# 11: "train loss:"0.61842, "train acc: "0.69952
# 11: "train loss:"0.53357, "train acc: "0.77404
# 11: "train loss:"0.55280, "train acc: "0.77163
# 11: "train loss:"0.59956, "train acc: "0.56971
# 11: "train loss:"0.61343, "train acc: "0.69231
# 11: "train loss:"0.49067, "train acc: "0.80529
# 11: "train loss:"0.66145, "train acc: "0.59615
# 11: "train loss:"0.48307, "train acc: "0.52163
# 11: "train loss:"0.66199, "train acc: "0.49038
# 11: "train loss:"0.60933, "train acc: "0.54567
# 11: "train loss:"0.45828, "train acc: "0.80288
# 11: "train loss:"0.57003, "train acc: "0.50721
# 11: "train loss:"0.44312, "train acc: "0.54087
# 11: "train loss:"0.59786, "train acc: "0.71154
# 11: "train loss:"0.54138, "train acc: "0.53846
# 11: "train loss:"0.49442, "train acc: "0.50962
# 11: "train loss:"0.48655, "train acc: "0.77404
# 11: "train loss:"0.42500, "train acc: "0.48798
# 11: "train loss:"0.66038, "train acc: "0.57212
# 11: "train loss:"0.40099, "train acc: "0.82212
# 11: "train loss:"0.50081, "train acc: "0.78846
# 11: "train loss:"0.47021, "train acc: "0.48798
# 11: "train loss:"0.66193, "train acc: "0.54567
# 11: "train loss:"0.49925, "train acc: "0.54087
# 11: "train loss:"0.59226, "train acc: "0.53125
# 11: "train loss:"0.49102, "train acc: "0.81010
# 11: "train loss:"0.53230, "train acc: "0.51923
# 11: "train loss:"0.64689, "train acc: "0.52404
# 11: "train loss:"0.65409, "train acc: "0.61538
# 11: "train loss:"0.64712, "train acc: "0.50721
# 11: "train loss:"0.63457, "train acc: "0.63702
# 11: "train loss:"0.58921, "train acc: "0.74038
# 11: "train loss:"0.63478, "train acc: "0.53365
# 11: "train loss:"0.61581, "train acc: "0.55288
# 11: "train loss:"0.43354, "train acc: "0.79567
# 11: "train loss:"0.52914, "train acc: "0.77163
# 11: "train loss:"0.44967, "train acc: "0.50000
# 11: "train loss:"0.43818, "train acc: "0.48317
# 11: "train loss:"0.49585, "train acc: "0.53125
# 11: "train loss:"0.54198, "train acc: "0.76923
# 11: "train loss:"0.67265, "train acc: "0.57692
# 11: "train loss:"0.59719, "train acc: "0.54327
# 11: "train loss:"0.65330, "train acc: "0.67548
# 11: "train loss:"0.63047, "train acc: "0.52404
# 11: "train loss:"0.63520, "train acc: "0.61538
# 11: "train loss:"0.60631, "train acc: "0.52163
# 11: "train loss:"0.58991, "train acc: "0.67308
# 11: "train loss:"0.53469, "train acc: "0.75962
# 11: "train loss:"0.63364, "train acc: "0.67308
# 11: "train loss:"0.53834, "train acc: "0.76923
# 11: "train loss:"0.48335, "train acc: "0.79327
# 11: "train loss:"0.48251, "train acc: "0.80529
# 11: "train loss:"0.57170, "train acc: "0.54327
# 11: "train loss:"0.65918, "train acc: "0.65865
# 11: "train loss:"0.58826, "train acc: "0.59375
# 11: "train loss:"0.58452, "train acc: "0.72596
# 11: "train loss:"0.51348, "train acc: "0.54327
# 11: "train loss:"0.53415, "train acc: "0.75000
# 11: "train loss:"0.54765, "train acc: "0.76923
# 11: "train loss:"0.51438, "train acc: "0.73558
# 11: "train loss:"0.49345, "train acc: "0.52644
# 11: "train loss:"0.59611, "train acc: "0.68510
# 11: "train loss:"0.55213, "train acc: "0.78365
# 11: "train loss:"0.40419, "train acc: "0.81010
# 11: "train loss:"0.67454, "train acc: "0.59615
# 11: "train loss:"0.58307, "train acc: "0.72596
# 11: "train loss:"0.60313, "train acc: "0.52163
# 11: "train loss:"0.57538, "train acc: "0.56731
# 11: "train loss:"0.59314, "train acc: "0.69231
# 11: "train loss:"0.62294, "train acc: "0.69231
# 11: "train loss:"0.53651, "train acc: "0.50962
# 11: "train loss:"0.58552, "train acc: "0.74760
# 11: "train loss:"0.63465, "train acc: "0.70433
# 11: "train loss:"0.54668, "train acc: "0.53606
# 11: "train loss:"0.64331, "train acc: "0.56971
# 11: "train loss:"0.63773, "train acc: "0.68029
# 11: "train loss:"0.65191, "train acc: "0.60096
# 11: "train loss:"0.59813, "train acc: "0.73798
# 11: "train loss:"0.43785, "train acc: "0.79808
# 11: "train loss:"0.64441, "train acc: "0.55769
# 11: "train loss:"0.51528, "train acc: "0.54087
# 11: "train loss:"0.58347, "train acc: "0.72837
# 11: "train loss:"0.55845, "train acc: "0.73317
# 11: "train loss:"0.60919, "train acc: "0.69231
# 11: "train loss:"0.57172, "train acc: "0.75240
# 11: "train loss:"0.59549, "train acc: "0.54567
# 11: "train loss:"0.62226, "train acc: "0.63221
# 11: "train loss:"0.64468, "train acc: "0.56731
# 11: "train loss:"0.61749, "train acc: "0.60817
# 11: "train loss:"0.61874, "train acc: "0.66587
# 11: "train loss:"0.50986, "train acc: "0.77885
# 11: "train loss:"0.46667, "train acc: "0.46875
# 11: "train loss:"0.59007, "train acc: "0.53606
# 11: "train loss:"0.51993, "train acc: "0.79567
# 11: "train loss:"0.52143, "train acc: "0.78846
# 11: "train loss:"0.56504, "train acc: "0.78125
# 11: "train loss:"0.61502, "train acc: "0.68990
# 11: "train loss:"0.44065, "train acc: "0.59135
# 11: "train loss:"0.65674, "train acc: "0.58173
# 11: "train loss:"0.64475, "train acc: "0.62500
# 11: "train loss:"0.63132, "train acc: "0.54327
# 11: "train loss:"0.57071, "train acc: "0.75962
# 11: "train loss:"0.60324, "train acc: "0.50000
# 11: "train loss:"0.63132, "train acc: "0.69231
# 11: "train loss:"0.47821, "train acc: "0.80288
# 11: "train loss:"0.62723, "train acc: "0.53125
# 11: "train loss:"0.62754, "train acc: "0.70433
# 11: "train loss:"0.44823, "train acc: "0.80529
# 11: "train loss:"0.44740, "train acc: "0.81490
# 11: "train loss:"0.64044, "train acc: "0.49760
# 11: "train loss:"0.62253, "train acc: "0.71635
# 11: "train loss:"0.50893, "train acc: "0.75962
# 11: "train loss:"0.59719, "train acc: "0.75481
# 11: "train loss:"0.62190, "train acc: "0.69471
# 11: "train loss:"0.62968, "train acc: "0.54327
# 11: "train loss:"0.47062, "train acc: "0.80048
# 11: "train loss:"0.56323, "train acc: "0.77404
# 11: "train loss:"0.57495, "train acc: "0.53846
# 11: "train loss:"0.60322, "train acc: "0.64423
# 11: "train loss:"0.46328, "train acc: "0.49760
# 11: "train loss:"0.52952, "train acc: "0.76442
# 11: "train loss:"0.57878, "train acc: "0.71875
# 11: "train loss:"0.52655, "train acc: "0.77885
# 11: "train loss:"0.64822, "train acc: "0.64663
# 11: "train loss:"0.56393, "train acc: "0.75962
# 11: "train loss:"0.51165, "train acc: "0.53365
# 11: "train loss:"0.49193, "train acc: "0.50962
# 11: "train loss:"0.52973, "train acc: "0.75000
# 11: "train loss:"0.54388, "train acc: "0.77644
# 11: "train loss:"0.52248, "train acc: "0.78846
# 11: "train loss:"0.55964, "train acc: "0.77163
# 11: "train loss:"0.51135, "train acc: "0.51683
# 11: "train loss:"0.40522, "train acc: "0.82452
# 11: "train loss:"0.47708, "train acc: "0.79567
# 11: "train loss:"0.48710, "train acc: "0.78846
# 11: "train loss:"0.47455, "train acc: "0.80048
# 11: "train loss:"0.63736, "train acc: "0.59375
# 11: "train loss:"0.53328, "train acc: "0.79087
# 11: "train loss:"0.61048, "train acc: "0.60096
# 11: "train loss:"0.49706, "train acc: "0.81250
# 11: "train loss:"0.54364, "train acc: "0.75000
# 11: "train loss:"0.56964, "train acc: "0.53125
# 11: "train loss:"0.66547, "train acc: "0.55288
# 11: "train loss:"0.48492, "train acc: "0.82212
# 11: "train loss:"0.64350, "train acc: "0.57692
# 11: "train loss:"0.60507, "train acc: "0.54327
# 11: "train loss:"0.44520, "train acc: "0.59375
# 11: "train loss:"0.59863, "train acc: "0.56010
# 11: "train loss:"0.54077, "train acc: "0.77644
# 11: "train loss:"0.44268, "train acc: "0.49519
# 11: "train loss:"0.65091, "train acc: "0.69471
# 11: "train loss:"0.45829, "train acc: "0.79087
# 11: "train loss:"0.53689, "train acc: "0.79567
# 11: "train loss:"0.64742, "train acc: "0.61779
# 11: "train loss:"0.55771, "train acc: "0.59135
# 11: "train loss:"0.63931, "train acc: "0.62260
# 11: "train loss:"0.43441, "train acc: "0.79808
# 11: "train loss:"0.63339, "train acc: "0.66827
# 11: "train loss:"0.47459, "train acc: "0.51923
# 11: "train loss:"0.60661, "train acc: "0.66346
# 11: "train loss:"0.56413, "train acc: "0.50000
# 11: "train loss:"0.67846, "train acc: "0.56731
# 11: "train loss:"0.43839, "train acc: "0.79327
# 11: "train loss:"0.45993, "train acc: "0.45673
# 11: "train loss:"0.41627, "train acc: "0.56971
# 11: "train loss:"0.59997, "train acc: "0.53846
# 11: "train loss:"0.62795, "train acc: "0.68029
# 11: "train loss:"0.47314, "train acc: "0.78846
# 11: "train loss:"0.63380, "train acc: "0.66106
# 11: "train loss:"0.58009, "train acc: "0.75962
# 11: "train loss:"0.57678, "train acc: "0.52404
# 11: "train loss:"0.62842, "train acc: "0.52885
# 11: "train loss:"0.68486, "train acc: "0.52404
# 11: "train loss:"0.56240, "train acc: "0.51442
# 11: "train loss:"0.56866, "train acc: "0.75962
# 11: "train loss:"0.62792, "train acc: "0.67067
# 11: "train loss:"0.64855, "train acc: "0.58654
# 11: "train loss:"0.49341, "train acc: "0.47837
# 11: "train loss:"0.56934, "train acc: "0.73798
# 11: "train loss:"0.43895, "train acc: "0.81490
# 11: "train loss:"0.65366, "train acc: "0.60817
# 11: "train loss:"0.65713, "train acc: "0.58173
# 11: "train loss:"0.63933, "train acc: "0.63942
# 11: "train loss:"0.49585, "train acc: "0.51683
# 11: "train loss:"0.47546, "train acc: "0.79087
# 11: "train loss:"0.53022, "train acc: "0.74760
# 11: "train loss:"0.51581, "train acc: "0.54327
# 11: "train loss:"0.65115, "train acc: "0.55048
# 11: "train loss:"0.45177, "train acc: "0.81971
# 11: "train loss:"0.56968, "train acc: "0.73798
# 11: "train loss:"0.57660, "train acc: "0.75240
# 11: "train loss:"0.62590, "train acc: "0.65144
# 11: "train loss:"0.46271, "train acc: "0.82212
# 11: "train loss:"0.57283, "train acc: "0.75481
# 11: "train loss:"0.53748, "train acc: "0.53606
# 11: "train loss:"0.46995, "train acc: "0.52404
# 11: "train loss:"0.50556, "train acc: "0.51202
# 11: "train loss:"0.62641, "train acc: "0.53125
# 11: "train loss:"0.59732, "train acc: "0.74279
# 11: "train loss:"0.57352, "train acc: "0.55529
# 11: "train loss:"0.60799, "train acc: "0.74519
# 11: "train loss:"0.47294, "train acc: "0.55048
# 11: "train loss:"0.65981, "train acc: "0.64183
# 11: "train loss:"0.58036, "train acc: "0.51202
# 11: "val loss:"0.36981, "val acc: "0.82212
# 11: "val loss:"0.45149, "val acc: "0.79808
# 11: "val loss:"0.52126, "val acc: "0.73077
# 11: "val loss:"0.46993, "val acc: "0.79808
# 11: "val loss:"0.44022, "val acc: "0.81250
# 11: "val loss:"0.60022, "val acc: "0.73558
# 11: "val loss:"0.37710, "val acc: "0.84615
# 11: "val loss:"0.48446, "val acc: "0.76442
# 11: "val loss:"0.46801, "val acc: "0.78365
# 11: "val loss:"0.58504, "val acc: "0.70673
# 11: "val loss:"0.48599, "val acc: "0.75962
# 11: "val loss:"0.41854, "val acc: "0.79327
# 11: "val loss:"0.43001, "val acc: "0.80769
# 11: "val loss:"0.53421, "val acc: "0.75481
# 11: "val loss:"0.46771, "val acc: "0.77885
# 11: "val loss:"0.58553, "val acc: "0.71154
# 11: "val loss:"0.35674, "val acc: "0.81731
# 11: "val loss:"0.33263, "val acc: "0.84615
# 11: "val loss:"0.45952, "val acc: "0.80288
# 11: "val loss:"0.45051, "val acc: "0.77885
# 11: "val loss:"0.43592, "val acc: "0.80769
# 11: "val loss:"0.53631, "val acc: "0.75481
# 11: "val loss:"0.45128, "val acc: "0.78846
# 11: "val loss:"0.41834, "val acc: "0.77404
# 11: "val loss:"0.50709, "val acc: "0.76923
# 11: "val loss:"0.33794, "val acc: "0.84135
# 11: "val loss:"0.49049, "val acc: "0.76442
# 11: "val loss:"0.45970, "val acc: "0.76442
# 11: "val loss:"0.48090, "val acc: "0.75481
# 11: "val loss:"0.48955, "val acc: "0.77404
# 11: "val loss:"0.52733, "val acc: "0.77885
# 11: "val loss:"0.59861, "val acc: "0.71635
# 11: "val loss:"0.42780, "val acc: "0.77404
# 11: "val loss:"0.52824, "val acc: "0.77885
# 11: "val loss:"0.36564, "val acc: "0.82692
# 11: "val loss:"0.45974, "val acc: "0.76442
# 11: "val loss:"0.43117, "val acc: "0.79327
# 11: "val loss:"0.41539, "val acc: "0.79808
# 11: "val loss:"0.36040, "val acc: "0.84135
# 11: "val loss:"0.39391, "val acc: "0.82212
# 11: "val loss:"0.42831, "val acc: "0.78846
# 11: "val loss:"0.39121, "val acc: "0.84135
# 11: "val loss:"0.46682, "val acc: "0.79327
# 11: "val loss:"0.49626, "val acc: "0.76923
# 11: "val loss:"0.43418, "val acc: "0.77404
# 11: "val loss:"0.42352, "val acc: "0.82212
# 11: "val loss:"0.44683, "val acc: "0.79327
# 11: "val loss:"0.42595, "val acc: "0.84135
# 11: "val loss:"0.35238, "val acc: "0.81731
# 11: "val loss:"0.53677, "val acc: "0.75000
# 11: "val loss:"0.44384, "val acc: "0.79808
# 11: "val loss:"0.43323, "val acc: "0.81250
# 11: "val loss:"0.37173, "val acc: "0.80769
# 11: "val loss:"0.42155, "val acc: "0.80288
# 11: "val loss:"0.42916, "val acc: "0.80288
# 11: "val loss:"0.41712, "val acc: "0.79808
# 11: "val loss:"0.42435, "val acc: "0.81731
# 11: "val loss:"0.41275, "val acc: "0.80769
# 11: "val loss:"0.46608, "val acc: "0.74519
# 11: "val loss:"0.49445, "val acc: "0.78365
# 11: "val loss:"0.38648, "val acc: "0.83173
# 11: "val loss:"0.49067, "val acc: "0.75000
# 11: "val loss:"0.50055, "val acc: "0.75962
# 11: "val loss:"0.45461, "val acc: "0.75000
# 11: "val loss:"0.43312, "val acc: "0.78365
# 11: "val loss:"0.41572, "val acc: "0.79808
# 11: "val loss:"0.47625, "val acc: "0.76442
# 11: "val loss:"0.37724, "val acc: "0.86058
# 11: "val loss:"0.39995, "val acc: "0.80769
# 11: "val loss:"0.42558, "val acc: "0.81250
# 11: "val loss:"0.51818, "val acc: "0.76442
# 11: "val loss:"0.48736, "val acc: "0.74519
# 11: "val loss:"0.46647, "val acc: "0.76923
# 11: "val loss:"0.43343, "val acc: "0.78846
# 11: "val loss:"0.39996, "val acc: "0.82212
# 11: "val loss:"0.50287, "val acc: "0.72596
# 11: "val loss:"0.46952, "val acc: "0.80288
# 11: "val loss:"0.49150, "val acc: "0.77885
# 11: "val loss:"0.39194, "val acc: "0.83654
# 11: "val loss:"0.45972, "val acc: "0.79327
# 11: "val loss:"0.47304, "val acc: "0.76442
# 11: "val loss:"0.48639, "val acc: "0.76923
# 11: "val loss:"0.53328, "val acc: "0.75962
# 11: "val loss:"0.44387, "val acc: "0.80769
# 11: "val loss:"0.44816, "val acc: "0.78365
# 11: "val loss:"0.30453, "val acc: "0.84135
# 11: "val loss:"0.47762, "val acc: "0.76923
# 11: "val loss:"0.42784, "val acc: "0.79808
# 11: "val loss:"0.41832, "val acc: "0.81250
# 11: "val loss:"0.39713, "val acc: "0.80288
# 11: "val loss:"0.50667, "val acc: "0.76923
# 11: "val loss:"0.40908, "val acc: "0.78846
# 11: "val loss:"0.45359, "val acc: "0.80769
# 11: "val loss:"0.41708, "val acc: "0.80288
# 11: "val loss:"0.42880, "val acc: "0.80288
# 11: "val loss:"0.44899, "val acc: "0.79327
# 11: "val loss:"0.35180, "val acc: "0.83654
# 11: "val loss:"0.34148, "val acc: "0.83173
# 11: "val loss:"0.43188, "val acc: "0.81250
# 11: "val loss:"0.37846, "val acc: "0.84135
# 11: "val loss:"0.42836, "val acc: "0.76923
# 11: "val loss:"0.50667, "val acc: "0.74519
# 11: "val loss:"0.42186, "val acc: "0.78846
# 11: "val loss:"0.46595, "val acc: "0.78365
# 11: "val loss:"0.45325, "val acc: "0.77885
# 11: "val loss:"0.42892, "val acc: "0.80288
# 11: "val loss:"0.51396, "val acc: "0.78365
# 11: "val loss:"0.38521, "val acc: "0.84615
# 11: "val loss:"0.44291, "val acc: "0.76923
# 11: "val loss:"0.46420, "val acc: "0.76923
# 11: "val loss:"0.33385, "val acc: "0.83654
# 11: "val loss:"0.39317, "val acc: "0.83173
# 11: "val loss:"0.43628, "val acc: "0.80288
# 11: "val loss:"0.42556, "val acc: "0.82212
# 11: "val loss:"0.41283, "val acc: "0.79327
# 11: "val loss:"0.44515, "val acc: "0.76442
# 11: "val loss:"0.43071, "val acc: "0.80769
# 11: "val loss:"0.43662, "val acc: "0.80769
# 11: "val loss:"0.37847, "val acc: "0.81250
# 11: "val loss:"0.50775, "val acc: "0.73077
# 11: "val loss:"0.38481, "val acc: "0.82212
# 11: "val loss:"0.49404, "val acc: "0.75962
# 11: "val loss:"0.40567, "val acc: "0.82212
# 11: "val loss:"0.44142, "val acc: "0.80769
# 11: "val loss:"0.51633, "val acc: "0.71154
# 12: "train loss:"0.64574, "train acc: "0.63462
# 12: "train loss:"0.60882, "train acc: "0.51923
# 12: "train loss:"0.62767, "train acc: "0.68750
# 12: "train loss:"0.58213, "train acc: "0.55288
# 12: "train loss:"0.63052, "train acc: "0.63462
# 12: "train loss:"0.66551, "train acc: "0.62981
# 12: "train loss:"0.60323, "train acc: "0.53606
# 12: "train loss:"0.48057, "train acc: "0.80048
# 12: "train loss:"0.61959, "train acc: "0.62260
# 12: "train loss:"0.65301, "train acc: "0.54087
# 12: "train loss:"0.61609, "train acc: "0.70673
# 12: "train loss:"0.60224, "train acc: "0.57452
# 12: "train loss:"0.46484, "train acc: "0.51442
# 12: "train loss:"0.55915, "train acc: "0.76683
# 12: "train loss:"0.63610, "train acc: "0.56490
# 12: "train loss:"0.57947, "train acc: "0.59375
# 12: "train loss:"0.60934, "train acc: "0.62500
# 12: "train loss:"0.44412, "train acc: "0.79567
# 12: "train loss:"0.63582, "train acc: "0.68510
# 12: "train loss:"0.62220, "train acc: "0.72837
# 12: "train loss:"0.45231, "train acc: "0.78606
# 12: "train loss:"0.63090, "train acc: "0.60096
# 12: "train loss:"0.62540, "train acc: "0.56490
# 12: "train loss:"0.54807, "train acc: "0.77404
# 12: "train loss:"0.59618, "train acc: "0.52644
# 12: "train loss:"0.47682, "train acc: "0.79567
# 12: "train loss:"0.59925, "train acc: "0.54087
# 12: "train loss:"0.61997, "train acc: "0.68750
# 12: "train loss:"0.65020, "train acc: "0.66827
# 12: "train loss:"0.58010, "train acc: "0.78606
# 12: "train loss:"0.63182, "train acc: "0.56731
# 12: "train loss:"0.43658, "train acc: "0.52404
# 12: "train loss:"0.56737, "train acc: "0.54567
# 12: "train loss:"0.59852, "train acc: "0.58173
# 12: "train loss:"0.57158, "train acc: "0.50240
# 12: "train loss:"0.51677, "train acc: "0.49519
# 12: "train loss:"0.62314, "train acc: "0.65625
# 12: "train loss:"0.62065, "train acc: "0.65625
# 12: "train loss:"0.60980, "train acc: "0.50962
# 12: "train loss:"0.50963, "train acc: "0.55529
# 12: "train loss:"0.46798, "train acc: "0.53606
# 12: "train loss:"0.62722, "train acc: "0.60337
# 12: "train loss:"0.50684, "train acc: "0.50721
# 12: "train loss:"0.60500, "train acc: "0.73317
# 12: "train loss:"0.58672, "train acc: "0.52163
# 12: "train loss:"0.51949, "train acc: "0.56010
# 12: "train loss:"0.52140, "train acc: "0.80288
# 12: "train loss:"0.62927, "train acc: "0.50240
# 12: "train loss:"0.60454, "train acc: "0.52404
# 12: "train loss:"0.59705, "train acc: "0.58894
# 12: "train loss:"0.41842, "train acc: "0.80048
# 12: "train loss:"0.47662, "train acc: "0.54808
# 12: "train loss:"0.46272, "train acc: "0.51683
# 12: "train loss:"0.62657, "train acc: "0.69952
# 12: "train loss:"0.46153, "train acc: "0.50000
# 12: "train loss:"0.48391, "train acc: "0.54087
# 12: "train loss:"0.60827, "train acc: "0.56731
# 12: "train loss:"0.51041, "train acc: "0.51923
# 12: "train loss:"0.49077, "train acc: "0.79087
# 12: "train loss:"0.64491, "train acc: "0.53846
# 12: "train loss:"0.60340, "train acc: "0.71154
# 12: "train loss:"0.51663, "train acc: "0.81250
# 12: "train loss:"0.48378, "train acc: "0.80288
# 12: "train loss:"0.46523, "train acc: "0.82212
# 12: "train loss:"0.62429, "train acc: "0.58413
# 12: "train loss:"0.54393, "train acc: "0.80048
# 12: "train loss:"0.49602, "train acc: "0.52644
# 12: "train loss:"0.55811, "train acc: "0.46875
# 12: "train loss:"0.64424, "train acc: "0.64423
# 12: "train loss:"0.54009, "train acc: "0.76683
# 12: "train loss:"0.56762, "train acc: "0.74279
# 12: "train loss:"0.42594, "train acc: "0.83173
# 12: "train loss:"0.54276, "train acc: "0.78125
# 12: "train loss:"0.55725, "train acc: "0.50962
# 12: "train loss:"0.60872, "train acc: "0.72837
# 12: "train loss:"0.42052, "train acc: "0.81971
# 12: "train loss:"0.58298, "train acc: "0.73558
# 12: "train loss:"0.57299, "train acc: "0.73558
# 12: "train loss:"0.48450, "train acc: "0.82452
# 12: "train loss:"0.48347, "train acc: "0.77644
# 12: "train loss:"0.57241, "train acc: "0.72356
# 12: "train loss:"0.64635, "train acc: "0.56010
# 12: "train loss:"0.51422, "train acc: "0.55529
# 12: "train loss:"0.58877, "train acc: "0.61298
# 12: "train loss:"0.63255, "train acc: "0.65625
# 12: "train loss:"0.66459, "train acc: "0.62981
# 12: "train loss:"0.62031, "train acc: "0.66346
# 12: "train loss:"0.47560, "train acc: "0.50240
# 12: "train loss:"0.50440, "train acc: "0.56971
# 12: "train loss:"0.61954, "train acc: "0.73798
# 12: "train loss:"0.50679, "train acc: "0.76442
# 12: "train loss:"0.42622, "train acc: "0.50962
# 12: "train loss:"0.61881, "train acc: "0.56490
# 12: "train loss:"0.66346, "train acc: "0.63702
# 12: "train loss:"0.54348, "train acc: "0.77644
# 12: "train loss:"0.41000, "train acc: "0.54567
# 12: "train loss:"0.43824, "train acc: "0.53365
# 12: "train loss:"0.61063, "train acc: "0.58173
# 12: "train loss:"0.48129, "train acc: "0.59615
# 12: "train loss:"0.43385, "train acc: "0.54087
# 12: "train loss:"0.52852, "train acc: "0.53846
# 12: "train loss:"0.63520, "train acc: "0.65865
# 12: "train loss:"0.56860, "train acc: "0.74279
# 12: "train loss:"0.41537, "train acc: "0.51683
# 12: "train loss:"0.52831, "train acc: "0.77885
# 12: "train loss:"0.63651, "train acc: "0.56490
# 12: "train loss:"0.63541, "train acc: "0.65144
# 12: "train loss:"0.51778, "train acc: "0.51202
# 12: "train loss:"0.41352, "train acc: "0.54327
# 12: "train loss:"0.41898, "train acc: "0.80529
# 12: "train loss:"0.63762, "train acc: "0.66346
# 12: "train loss:"0.62562, "train acc: "0.58413
# 12: "train loss:"0.62515, "train acc: "0.54327
# 12: "train loss:"0.52347, "train acc: "0.51923
# 12: "train loss:"0.65573, "train acc: "0.62260
# 12: "train loss:"0.51872, "train acc: "0.47837
# 12: "train loss:"0.59912, "train acc: "0.76442
# 12: "train loss:"0.49684, "train acc: "0.54087
# 12: "train loss:"0.67332, "train acc: "0.55048
# 12: "train loss:"0.46057, "train acc: "0.81971
# 12: "train loss:"0.61741, "train acc: "0.57933
# 12: "train loss:"0.42780, "train acc: "0.48558
# 12: "train loss:"0.57833, "train acc: "0.56250
# 12: "train loss:"0.51685, "train acc: "0.78606
# 12: "train loss:"0.62590, "train acc: "0.58173
# 12: "train loss:"0.57665, "train acc: "0.50000
# 12: "train loss:"0.64431, "train acc: "0.55529
# 12: "train loss:"0.58690, "train acc: "0.53606
# 12: "train loss:"0.64907, "train acc: "0.54808
# 12: "train loss:"0.43971, "train acc: "0.50481
# 12: "train loss:"0.62647, "train acc: "0.67308
# 12: "train loss:"0.53896, "train acc: "0.54808
# 12: "train loss:"0.61295, "train acc: "0.48558
# 12: "train loss:"0.64892, "train acc: "0.62260
# 12: "train loss:"0.66737, "train acc: "0.58654
# 12: "train loss:"0.61289, "train acc: "0.71394
# 12: "train loss:"0.48300, "train acc: "0.83654
# 12: "train loss:"0.59055, "train acc: "0.55769
# 12: "train loss:"0.46117, "train acc: "0.55048
# 12: "train loss:"0.48277, "train acc: "0.53365
# 12: "train loss:"0.45179, "train acc: "0.51442
# 12: "train loss:"0.51921, "train acc: "0.80529
# 12: "train loss:"0.57521, "train acc: "0.50721
# 12: "train loss:"0.55546, "train acc: "0.57692
# 12: "train loss:"0.61780, "train acc: "0.73798
# 12: "train loss:"0.53324, "train acc: "0.51683
# 12: "train loss:"0.51344, "train acc: "0.78125
# 12: "train loss:"0.54621, "train acc: "0.77163
# 12: "train loss:"0.59770, "train acc: "0.53125
# 12: "train loss:"0.55701, "train acc: "0.77885
# 12: "train loss:"0.63714, "train acc: "0.62981
# 12: "train loss:"0.62893, "train acc: "0.58413
# 12: "train loss:"0.63307, "train acc: "0.71635
# 12: "train loss:"0.58467, "train acc: "0.73077
# 12: "train loss:"0.56624, "train acc: "0.52163
# 12: "train loss:"0.59380, "train acc: "0.49279
# 12: "train loss:"0.61307, "train acc: "0.46875
# 12: "train loss:"0.59615, "train acc: "0.72356
# 12: "train loss:"0.56858, "train acc: "0.49279
# 12: "train loss:"0.43592, "train acc: "0.83173
# 12: "train loss:"0.41296, "train acc: "0.49760
# 12: "train loss:"0.44240, "train acc: "0.82933
# 12: "train loss:"0.64304, "train acc: "0.62981
# 12: "train loss:"0.46662, "train acc: "0.80288
# 12: "train loss:"0.41541, "train acc: "0.49519
# 12: "train loss:"0.53287, "train acc: "0.51923
# 12: "train loss:"0.49565, "train acc: "0.52163
# 12: "train loss:"0.47141, "train acc: "0.80529
# 12: "train loss:"0.60641, "train acc: "0.56490
# 12: "train loss:"0.43543, "train acc: "0.81971
# 12: "train loss:"0.62327, "train acc: "0.53606
# 12: "train loss:"0.54617, "train acc: "0.52885
# 12: "train loss:"0.67737, "train acc: "0.53606
# 12: "train loss:"0.58923, "train acc: "0.73558
# 12: "train loss:"0.63252, "train acc: "0.68990
# 12: "train loss:"0.41695, "train acc: "0.80769
# 12: "train loss:"0.52486, "train acc: "0.50000
# 12: "train loss:"0.57273, "train acc: "0.48798
# 12: "train loss:"0.58789, "train acc: "0.57452
# 12: "train loss:"0.45723, "train acc: "0.56731
# 12: "train loss:"0.64377, "train acc: "0.60337
# 12: "train loss:"0.48742, "train acc: "0.77163
# 12: "train loss:"0.60480, "train acc: "0.59135
# 12: "train loss:"0.43730, "train acc: "0.81250
# 12: "train loss:"0.47009, "train acc: "0.50481
# 12: "train loss:"0.41993, "train acc: "0.79327
# 12: "train loss:"0.49763, "train acc: "0.80288
# 12: "train loss:"0.49049, "train acc: "0.50721
# 12: "train loss:"0.60324, "train acc: "0.75000
# 12: "train loss:"0.49384, "train acc: "0.56971
# 12: "train loss:"0.64024, "train acc: "0.57692
# 12: "train loss:"0.63533, "train acc: "0.50962
# 12: "train loss:"0.44477, "train acc: "0.82212
# 12: "train loss:"0.60325, "train acc: "0.73798
# 12: "train loss:"0.56248, "train acc: "0.45433
# 12: "train loss:"0.53795, "train acc: "0.52885
# 12: "train loss:"0.63494, "train acc: "0.61058
# 12: "train loss:"0.42606, "train acc: "0.46635
# 12: "train loss:"0.61343, "train acc: "0.70433
# 12: "train loss:"0.52903, "train acc: "0.56250
# 12: "train loss:"0.40886, "train acc: "0.54808
# 12: "train loss:"0.58907, "train acc: "0.58413
# 12: "train loss:"0.62290, "train acc: "0.71635
# 12: "train loss:"0.44901, "train acc: "0.53846
# 12: "train loss:"0.64420, "train acc: "0.51683
# 12: "train loss:"0.36129, "train acc: "0.56490
# 12: "train loss:"0.45210, "train acc: "0.82212
# 12: "train loss:"0.49824, "train acc: "0.75721
# 12: "train loss:"0.50570, "train acc: "0.51202
# 12: "train loss:"0.40810, "train acc: "0.51202
# 12: "train loss:"0.59884, "train acc: "0.58173
# 12: "train loss:"0.46354, "train acc: "0.79808
# 12: "train loss:"0.58287, "train acc: "0.57933
# 12: "train loss:"0.50406, "train acc: "0.80769
# 12: "train loss:"0.60467, "train acc: "0.75962
# 12: "train loss:"0.41879, "train acc: "0.46394
# 12: "train loss:"0.63964, "train acc: "0.68510
# 12: "train loss:"0.55833, "train acc: "0.76202
# 12: "train loss:"0.53916, "train acc: "0.50000
# 12: "train loss:"0.66099, "train acc: "0.59135
# 12: "train loss:"0.48547, "train acc: "0.81731
# 12: "train loss:"0.66105, "train acc: "0.57452
# 12: "train loss:"0.62031, "train acc: "0.70433
# 12: "train loss:"0.66582, "train acc: "0.52163
# 12: "train loss:"0.50317, "train acc: "0.48077
# 12: "train loss:"0.61069, "train acc: "0.69471
# 12: "train loss:"0.42378, "train acc: "0.53365
# 12: "train loss:"0.54570, "train acc: "0.51923
# 12: "train loss:"0.60542, "train acc: "0.63702
# 12: "train loss:"0.62012, "train acc: "0.71635
# 12: "train loss:"0.59450, "train acc: "0.63221
# 12: "train loss:"0.60413, "train acc: "0.72837
# 12: "train loss:"0.48879, "train acc: "0.80769
# 12: "train loss:"0.59390, "train acc: "0.71154
# 12: "train loss:"0.55481, "train acc: "0.54327
# 12: "train loss:"0.58136, "train acc: "0.74519
# 12: "train loss:"0.48262, "train acc: "0.45673
# 12: "train loss:"0.47034, "train acc: "0.53606
# 12: "train loss:"0.51434, "train acc: "0.81250
# 12: "train loss:"0.49997, "train acc: "0.78365
# 12: "train loss:"0.42503, "train acc: "0.83894
# 12: "train loss:"0.44658, "train acc: "0.52404
# 12: "train loss:"0.63287, "train acc: "0.73077
# 12: "train loss:"0.44521, "train acc: "0.81971
# 12: "train loss:"0.52906, "train acc: "0.77644
# 12: "train loss:"0.63384, "train acc: "0.57692
# 12: "train loss:"0.47399, "train acc: "0.83894
# 12: "train loss:"0.52986, "train acc: "0.78365
# 12: "train loss:"0.49899, "train acc: "0.77885
# 12: "train loss:"0.52193, "train acc: "0.56490
# 12: "val loss:"0.39871, "val acc: "0.78846
# 12: "val loss:"0.40579, "val acc: "0.77404
# 12: "val loss:"0.57074, "val acc: "0.71154
# 12: "val loss:"0.40167, "val acc: "0.81731
# 12: "val loss:"0.46493, "val acc: "0.79327
# 12: "val loss:"0.48500, "val acc: "0.76923
# 12: "val loss:"0.34979, "val acc: "0.83654
# 12: "val loss:"0.41619, "val acc: "0.79327
# 12: "val loss:"0.46561, "val acc: "0.78846
# 12: "val loss:"0.48195, "val acc: "0.77885
# 12: "val loss:"0.44758, "val acc: "0.77404
# 12: "val loss:"0.47707, "val acc: "0.77404
# 12: "val loss:"0.38063, "val acc: "0.83654
# 12: "val loss:"0.51559, "val acc: "0.76923
# 12: "val loss:"0.40862, "val acc: "0.80769
# 12: "val loss:"0.53717, "val acc: "0.75481
# 12: "val loss:"0.42539, "val acc: "0.78846
# 12: "val loss:"0.32821, "val acc: "0.87019
# 12: "val loss:"0.44283, "val acc: "0.79808
# 12: "val loss:"0.45347, "val acc: "0.75962
# 12: "val loss:"0.43895, "val acc: "0.78846
# 12: "val loss:"0.43591, "val acc: "0.79808
# 12: "val loss:"0.45119, "val acc: "0.79327
# 12: "val loss:"0.44231, "val acc: "0.79327
# 12: "val loss:"0.39792, "val acc: "0.82692
# 12: "val loss:"0.29619, "val acc: "0.87500
# 12: "val loss:"0.40398, "val acc: "0.80769
# 12: "val loss:"0.43108, "val acc: "0.81250
# 12: "val loss:"0.51299, "val acc: "0.75481
# 12: "val loss:"0.52451, "val acc: "0.77404
# 12: "val loss:"0.50836, "val acc: "0.75481
# 12: "val loss:"0.55394, "val acc: "0.75481
# 12: "val loss:"0.37867, "val acc: "0.83654
# 12: "val loss:"0.48760, "val acc: "0.78846
# 12: "val loss:"0.38945, "val acc: "0.80288
# 12: "val loss:"0.44847, "val acc: "0.77885
# 12: "val loss:"0.47623, "val acc: "0.75962
# 12: "val loss:"0.39040, "val acc: "0.78846
# 12: "val loss:"0.38199, "val acc: "0.85577
# 12: "val loss:"0.41226, "val acc: "0.80288
# 12: "val loss:"0.37124, "val acc: "0.83173
# 12: "val loss:"0.42448, "val acc: "0.77404
# 12: "val loss:"0.43504, "val acc: "0.80288
# 12: "val loss:"0.49274, "val acc: "0.76442
# 12: "val loss:"0.38764, "val acc: "0.81731
# 12: "val loss:"0.37435, "val acc: "0.83654
# 12: "val loss:"0.48264, "val acc: "0.80769
# 12: "val loss:"0.41146, "val acc: "0.81731
# 12: "val loss:"0.38854, "val acc: "0.78846
# 12: "val loss:"0.52593, "val acc: "0.72596
# 12: "val loss:"0.42842, "val acc: "0.79327
# 12: "val loss:"0.41573, "val acc: "0.78846
# 12: "val loss:"0.39175, "val acc: "0.79327
# 12: "val loss:"0.44640, "val acc: "0.79327
# 12: "val loss:"0.40552, "val acc: "0.79808
# 12: "val loss:"0.44780, "val acc: "0.79327
# 12: "val loss:"0.40801, "val acc: "0.80769
# 12: "val loss:"0.37941, "val acc: "0.81250
# 12: "val loss:"0.42157, "val acc: "0.80769
# 12: "val loss:"0.47327, "val acc: "0.76923
# 12: "val loss:"0.33505, "val acc: "0.84615
# 12: "val loss:"0.48679, "val acc: "0.80288
# 12: "val loss:"0.44938, "val acc: "0.77885
# 12: "val loss:"0.46946, "val acc: "0.78365
# 12: "val loss:"0.43564, "val acc: "0.80769
# 12: "val loss:"0.40129, "val acc: "0.82692
# 12: "val loss:"0.46282, "val acc: "0.72596
# 12: "val loss:"0.45167, "val acc: "0.81731
# 12: "val loss:"0.46581, "val acc: "0.75481
# 12: "val loss:"0.45418, "val acc: "0.78365
# 12: "val loss:"0.48191, "val acc: "0.77885
# 12: "val loss:"0.47971, "val acc: "0.78365
# 12: "val loss:"0.48015, "val acc: "0.75481
# 12: "val loss:"0.36872, "val acc: "0.81250
# 12: "val loss:"0.42113, "val acc: "0.81250
# 12: "val loss:"0.50487, "val acc: "0.74519
# 12: "val loss:"0.37314, "val acc: "0.82692
# 12: "val loss:"0.55856, "val acc: "0.76442
# 12: "val loss:"0.35993, "val acc: "0.83654
# 12: "val loss:"0.38799, "val acc: "0.82692
# 12: "val loss:"0.43263, "val acc: "0.78846
# 12: "val loss:"0.43750, "val acc: "0.78846
# 12: "val loss:"0.51834, "val acc: "0.75481
# 12: "val loss:"0.38128, "val acc: "0.80288
# 12: "val loss:"0.42040, "val acc: "0.79808
# 12: "val loss:"0.32024, "val acc: "0.84615
# 12: "val loss:"0.49729, "val acc: "0.75962
# 12: "val loss:"0.40221, "val acc: "0.79808
# 12: "val loss:"0.36762, "val acc: "0.83173
# 12: "val loss:"0.39440, "val acc: "0.82212
# 12: "val loss:"0.48321, "val acc: "0.79808
# 12: "val loss:"0.44790, "val acc: "0.80288
# 12: "val loss:"0.45128, "val acc: "0.79327
# 12: "val loss:"0.49096, "val acc: "0.76923
# 12: "val loss:"0.39278, "val acc: "0.80769
# 12: "val loss:"0.39211, "val acc: "0.78846
# 12: "val loss:"0.36429, "val acc: "0.85096
# 12: "val loss:"0.40227, "val acc: "0.82212
# 12: "val loss:"0.41080, "val acc: "0.81731
# 12: "val loss:"0.37034, "val acc: "0.84135
# 12: "val loss:"0.43682, "val acc: "0.79808
# 12: "val loss:"0.44028, "val acc: "0.77404
# 12: "val loss:"0.48043, "val acc: "0.76923
# 12: "val loss:"0.47505, "val acc: "0.74038
# 12: "val loss:"0.42901, "val acc: "0.78365
# 12: "val loss:"0.39064, "val acc: "0.80288
# 12: "val loss:"0.49961, "val acc: "0.76442
# 12: "val loss:"0.37034, "val acc: "0.83654
# 12: "val loss:"0.43932, "val acc: "0.82212
# 12: "val loss:"0.40804, "val acc: "0.81731
# 12: "val loss:"0.31556, "val acc: "0.84615
# 12: "val loss:"0.41098, "val acc: "0.81731
# 12: "val loss:"0.47886, "val acc: "0.78846
# 12: "val loss:"0.42925, "val acc: "0.79808
# 12: "val loss:"0.40899, "val acc: "0.78846
# 12: "val loss:"0.52429, "val acc: "0.75962
# 12: "val loss:"0.41430, "val acc: "0.81731
# 12: "val loss:"0.44822, "val acc: "0.75962
# 12: "val loss:"0.36783, "val acc: "0.80288
# 12: "val loss:"0.48529, "val acc: "0.77404
# 12: "val loss:"0.41755, "val acc: "0.80769
# 12: "val loss:"0.50159, "val acc: "0.76442
# 12: "val loss:"0.38013, "val acc: "0.79808
# 12: "val loss:"0.40486, "val acc: "0.80769
# 12: "val loss:"0.45450, "val acc: "0.77404
# 13: "train loss:"0.63926, "train acc: "0.73798
# 13: "train loss:"0.62462, "train acc: "0.68990
# 13: "train loss:"0.44581, "train acc: "0.83413
# 13: "train loss:"0.52836, "train acc: "0.50481
# 13: "train loss:"0.56172, "train acc: "0.76923
# 13: "train loss:"0.63094, "train acc: "0.68750
# 13: "train loss:"0.62679, "train acc: "0.66346
# 13: "train loss:"0.53924, "train acc: "0.51202
# 13: "train loss:"0.63339, "train acc: "0.69712
# 13: "train loss:"0.59700, "train acc: "0.55769
# 13: "train loss:"0.60505, "train acc: "0.58173
# ...
# 22: "val loss:"0.38473, "val acc: "0.86058
# 22: "val loss:"0.46266, "val acc: "0.81731
# 22: "val loss:"0.50279, "val acc: "0.78365
# 22: "val loss:"0.34706, "val acc: "0.84615
# 22: "val loss:"0.34633, "val acc: "0.88462
# 22: "val loss:"0.26317, "val acc: "0.90865
# 22: "val loss:"0.44448, "val acc: "0.82692
# 22: "val loss:"0.30946, "val acc: "0.86058
# 22: "val loss:"0.34220, "val acc: "0.85577
# 22: "val loss:"0.26707, "val acc: "0.89904
# 22: "val loss:"0.34975, "val acc: "0.87019
# 22: "val loss:"0.28247, "val acc: "0.87500
# 22: "val loss:"0.29328, "val acc: "0.88462
# 22: "val loss:"0.30504, "val acc: "0.86538
# 22: "val loss:"0.32895, "val acc: "0.87500
# 22: "val loss:"0.32937, "val acc: "0.86058
# 22: "val loss:"0.27342, "val acc: "0.88462
# 22: "val loss:"0.27627, "val acc: "0.90385
# 22: "val loss:"0.28246, "val acc: "0.87500
# 22: "val loss:"0.28095, "val acc: "0.87500
# 22: "val loss:"0.45129, "val acc: "0.81250
# 22: "val loss:"0.29461, "val acc: "0.91346
# 22: "val loss:"0.36254, "val acc: "0.85577
# 22: "val loss:"0.29897, "val acc: "0.87981
# 22: "val loss:"0.36712, "val acc: "0.86538
# 22: "val loss:"0.28869, "val acc: "0.87019
# 22: "val loss:"0.27449, "val acc: "0.89904
# 22: "val loss:"0.33042, "val acc: "0.87981
# 22: "val loss:"0.28154, "val acc: "0.89904
# 22: "val loss:"0.36721, "val acc: "0.84615
# 22: "val loss:"0.44392, "val acc: "0.83654
# 22: "val loss:"0.33236, "val acc: "0.88942
# 22: "val loss:"0.39385, "val acc: "0.83654
# 22: "val loss:"0.40922, "val acc: "0.82212
# 22: "val loss:"0.35433, "val acc: "0.82692
# 22: "val loss:"0.28828, "val acc: "0.86058
# 22: "val loss:"0.22513, "val acc: "0.89904
# 22: "val loss:"0.45786, "val acc: "0.81250
# 22: "val loss:"0.29201, "val acc: "0.88462
# 22: "val loss:"0.40453, "val acc: "0.82692
# 22: "val loss:"0.34864, "val acc: "0.86058
# 22: "val loss:"0.46081, "val acc: "0.82212
# 22: "val loss:"0.33264, "val acc: "0.87019
# 22: "val loss:"0.42617, "val acc: "0.84615
# 22: "val loss:"0.31609, "val acc: "0.85577
# 22: "val loss:"0.31220, "val acc: "0.86538
# 22: "val loss:"0.30476, "val acc: "0.86538
# 22: "val loss:"0.29337, "val acc: "0.90865
# 22: "val loss:"0.44015, "val acc: "0.81250
# 22: "val loss:"0.32662, "val acc: "0.89423
# 22: "val loss:"0.29170, "val acc: "0.87981
# 22: "val loss:"0.31831, "val acc: "0.87981
# 22: "val loss:"0.36170, "val acc: "0.85096
# 22: "val loss:"0.42375, "val acc: "0.83654
# 22: "val loss:"0.30552, "val acc: "0.90385
# 22: "val loss:"0.30409, "val acc: "0.87019
# 22: "val loss:"0.24245, "val acc: "0.89423
# 22: "val loss:"0.31951, "val acc: "0.86058
# 22: "val loss:"0.46675, "val acc: "0.81250
# 22: "val loss:"0.28202, "val acc: "0.88942
# 22: "val loss:"0.29597, "val acc: "0.88942
# 22: "val loss:"0.36624, "val acc: "0.87981
# 22: "val loss:"0.33589, "val acc: "0.89423
# 22: "val loss:"0.29796, "val acc: "0.87500
# 22: "val loss:"0.30740, "val acc: "0.84615
# 22: "val loss:"0.37086, "val acc: "0.86058
# 22: "val loss:"0.29175, "val acc: "0.85096
# 22: "val loss:"0.26804, "val acc: "0.89423
# 22: "val loss:"0.28712, "val acc: "0.87500
# 22: "val loss:"0.28358, "val acc: "0.90385
# 22: "val loss:"0.29611, "val acc: "0.88462
# 22: "val loss:"0.31556, "val acc: "0.86058
# 22: "val loss:"0.39462, "val acc: "0.81250
# 22: "val loss:"0.29092, "val acc: "0.88942
# 22: "val loss:"0.36751, "val acc: "0.86058
# 22: "val loss:"0.31028, "val acc: "0.88942
# 22: "val loss:"0.32501, "val acc: "0.88462
# 22: "val loss:"0.37210, "val acc: "0.85096
# 22: "val loss:"0.28416, "val acc: "0.87500
# 22: "val loss:"0.31250, "val acc: "0.87981
# 22: "val loss:"0.34133, "val acc: "0.85577
# 22: "val loss:"0.25868, "val acc: "0.90865
# 22: "val loss:"0.31486, "val acc: "0.87500
# 22: "val loss:"0.26656, "val acc: "0.89904
# 22: "val loss:"0.39439, "val acc: "0.86058
# 22: "val loss:"0.34264, "val acc: "0.85577
# 22: "val loss:"0.36763, "val acc: "0.85096
# 22: "val loss:"0.32939, "val acc: "0.85577
# 22: "val loss:"0.37349, "val acc: "0.86058
# 22: "val loss:"0.35037, "val acc: "0.86538
# 22: "val loss:"0.37457, "val acc: "0.84615
# 22: "val loss:"0.25151, "val acc: "0.88462
# 22: "val loss:"0.39838, "val acc: "0.83654
# 22: "val loss:"0.34033, "val acc: "0.87500
# 22: "val loss:"0.38532, "val acc: "0.81250
# 22: "val loss:"0.36835, "val acc: "0.83173
# 23: "train loss:"0.35492, "train acc: "0.88702
# 23: "train loss:"0.35218, "train acc: "0.90385
# 23: "train loss:"0.35851, "train acc: "0.89663
# 23: "train loss:"0.34341, "train acc: "0.61538
# 23: "train loss:"0.54044, "train acc: "0.83173
# 23: "train loss:"0.63415, "train acc: "0.67788
# 23: "train loss:"0.55143, "train acc: "0.67788
# 23: "train loss:"0.40314, "train acc: "0.88702
# 23: "train loss:"0.64022, "train acc: "0.67788
# 23: "train loss:"0.44969, "train acc: "0.47596
# 23: "train loss:"0.36062, "train acc: "0.89663
# 23: "train loss:"0.38617, "train acc: "0.87740
# 23: "train loss:"0.41217, "train acc: "0.84135
# 23: "train loss:"0.40740, "train acc: "0.85817
# 23: "train loss:"0.65633, "train acc: "0.67788
# 23: "train loss:"0.66278, "train acc: "0.57212
# 23: "train loss:"0.33128, "train acc: "0.51683
# 23: "train loss:"0.62581, "train acc: "0.53125
# 23: "train loss:"0.63617, "train acc: "0.65625
# 23: "train loss:"0.43087, "train acc: "0.84615
# 23: "train loss:"0.57143, "train acc: "0.50721
# 23: "train loss:"0.66190, "train acc: "0.63462
# 23: "train loss:"0.53408, "train acc: "0.53365
# 23: "train loss:"0.44982, "train acc: "0.52163
# 23: "train loss:"0.45534, "train acc: "0.54327
# 23: "train loss:"0.44149, "train acc: "0.83413
# 23: "train loss:"0.36793, "train acc: "0.47596
# 23: "train loss:"0.61079, "train acc: "0.68029
# 23: "train loss:"0.35141, "train acc: "0.88462
# 23: "train loss:"0.54074, "train acc: "0.56010
# 23: "train loss:"0.63622, "train acc: "0.68029
# 23: "train loss:"0.59833, "train acc: "0.75481
# 23: "train loss:"0.50691, "train acc: "0.84615
# 23: "train loss:"0.49995, "train acc: "0.55529
# 23: "train loss:"0.47470, "train acc: "0.82452
# 23: "train loss:"0.50966, "train acc: "0.75962
# 23: "train loss:"0.47212, "train acc: "0.54567
# 23: "train loss:"0.39118, "train acc: "0.90385
# 23: "train loss:"0.44138, "train acc: "0.86298
# 23: "train loss:"0.56182, "train acc: "0.78365
# 23: "train loss:"0.33717, "train acc: "0.87500
# 23: "train loss:"0.40742, "train acc: "0.58413
# 23: "train loss:"0.49515, "train acc: "0.54567
# 23: "train loss:"0.63864, "train acc: "0.49519
# 23: "train loss:"0.57709, "train acc: "0.62019
# 23: "train loss:"0.34921, "train acc: "0.53365
# 23: "train loss:"0.52276, "train acc: "0.84135
# 23: "train loss:"0.39161, "train acc: "0.88942
# 23: "train loss:"0.35611, "train acc: "0.50721
# 23: "train loss:"0.41471, "train acc: "0.86058
# 23: "train loss:"0.63910, "train acc: "0.55288
# 23: "train loss:"0.61657, "train acc: "0.55769
# 23: "train loss:"0.65875, "train acc: "0.65865
# 23: "train loss:"0.60284, "train acc: "0.75721
# 23: "train loss:"0.53229, "train acc: "0.81731
# 23: "train loss:"0.28205, "train acc: "0.54087
# 23: "train loss:"0.61769, "train acc: "0.72596
# 23: "train loss:"0.48416, "train acc: "0.85817
# 23: "train loss:"0.46829, "train acc: "0.59856
# 23: "train loss:"0.53453, "train acc: "0.82933
# 23: "train loss:"0.55924, "train acc: "0.54087
# 23: "train loss:"0.37154, "train acc: "0.87740
# 23: "train loss:"0.62175, "train acc: "0.67067
# 23: "train loss:"0.61303, "train acc: "0.62500
# 23: "train loss:"0.61403, "train acc: "0.59375
# 23: "train loss:"0.55809, "train acc: "0.52163
# 23: "train loss:"0.62431, "train acc: "0.57692
# 23: "train loss:"0.66528, "train acc: "0.56731
# 23: "train loss:"0.64221, "train acc: "0.47596
# 23: "train loss:"0.59622, "train acc: "0.78365
# 23: "train loss:"0.36013, "train acc: "0.85096
# 23: "train loss:"0.50173, "train acc: "0.86058
# 23: "train loss:"0.46642, "train acc: "0.86298
# 23: "train loss:"0.45031, "train acc: "0.84615
# 23: "train loss:"0.63140, "train acc: "0.62740
# 23: "train loss:"0.53481, "train acc: "0.53846
# 23: "train loss:"0.61068, "train acc: "0.66346
# 23: "train loss:"0.61001, "train acc: "0.70673
# 23: "train loss:"0.27832, "train acc: "0.89423
# 23: "train loss:"0.42025, "train acc: "0.90625
# 23: "train loss:"0.60649, "train acc: "0.67308
# 23: "train loss:"0.47107, "train acc: "0.85577
# 23: "train loss:"0.63363, "train acc: "0.53365
# 23: "train loss:"0.65243, "train acc: "0.52885
# 23: "train loss:"0.40962, "train acc: "0.87019
# 23: "train loss:"0.53005, "train acc: "0.85096
# 23: "train loss:"0.61260, "train acc: "0.59135
# 23: "train loss:"0.62266, "train acc: "0.75481
# 23: "train loss:"0.34758, "train acc: "0.49760
# 23: "train loss:"0.42215, "train acc: "0.52404
# 23: "train loss:"0.60287, "train acc: "0.76202
# 23: "train loss:"0.55070, "train acc: "0.57212
# 23: "train loss:"0.30931, "train acc: "0.46635
# 23: "train loss:"0.57281, "train acc: "0.80288
# 23: "train loss:"0.44900, "train acc: "0.52163
# 23: "train loss:"0.43043, "train acc: "0.87260
# 23: "train loss:"0.59931, "train acc: "0.60817
# 23: "train loss:"0.37469, "train acc: "0.88942
# 23: "train loss:"0.33279, "train acc: "0.89183
# 23: "train loss:"0.26323, "train acc: "0.54087
# 23: "train loss:"0.45206, "train acc: "0.85577
# 23: "train loss:"0.61881, "train acc: "0.68990
# 23: "train loss:"0.61420, "train acc: "0.52404
# 23: "train loss:"0.62539, "train acc: "0.57452
# 23: "train loss:"0.56861, "train acc: "0.50481
# 23: "train loss:"0.45843, "train acc: "0.53125
# 23: "train loss:"0.35250, "train acc: "0.49279
# 23: "train loss:"0.36010, "train acc: "0.88221
# 23: "train loss:"0.36265, "train acc: "0.87740
# 23: "train loss:"0.38774, "train acc: "0.50721
# 23: "train loss:"0.60398, "train acc: "0.75000
# 23: "train loss:"0.53305, "train acc: "0.49519
# 23: "train loss:"0.37850, "train acc: "0.87981
# 23: "train loss:"0.27459, "train acc: "0.54808
# 23: "train loss:"0.59659, "train acc: "0.78125
# 23: "train loss:"0.49787, "train acc: "0.84856
# 23: "train loss:"0.58882, "train acc: "0.52163
# 23: "train loss:"0.46468, "train acc: "0.86538
# 23: "train loss:"0.43946, "train acc: "0.85817
# 23: "train loss:"0.51455, "train acc: "0.50721
# 23: "train loss:"0.59474, "train acc: "0.70673
# 23: "train loss:"0.49279, "train acc: "0.51202
# 23: "train loss:"0.33808, "train acc: "0.87019
# 23: "train loss:"0.49811, "train acc: "0.82692
# 23: "train loss:"0.27672, "train acc: "0.91106
# 23: "train loss:"0.50086, "train acc: "0.51442
# 23: "train loss:"0.36065, "train acc: "0.52163
# 23: "train loss:"0.62036, "train acc: "0.58894
# 23: "train loss:"0.33164, "train acc: "0.52163
# 23: "train loss:"0.49756, "train acc: "0.86058
# 23: "train loss:"0.60114, "train acc: "0.63221
# 23: "train loss:"0.55252, "train acc: "0.81731
# 23: "train loss:"0.64344, "train acc: "0.65625
# 23: "train loss:"0.41930, "train acc: "0.52885
# 23: "train loss:"0.44211, "train acc: "0.47596
# 23: "train loss:"0.50639, "train acc: "0.49760
# 23: "train loss:"0.40247, "train acc: "0.89423
# 23: "train loss:"0.41860, "train acc: "0.56250
# 23: "train loss:"0.39415, "train acc: "0.88462
# 23: "train loss:"0.32562, "train acc: "0.56250
# 23: "train loss:"0.64591, "train acc: "0.58413
# 23: "train loss:"0.56814, "train acc: "0.50000
# 23: "train loss:"0.51841, "train acc: "0.84856
# 23: "train loss:"0.49547, "train acc: "0.82692
# 23: "train loss:"0.57434, "train acc: "0.50962
# 23: "train loss:"0.65137, "train acc: "0.59856
# 23: "train loss:"0.44628, "train acc: "0.55288
# 23: "train loss:"0.27485, "train acc: "0.54808
# 23: "train loss:"0.41271, "train acc: "0.89423
# 23: "train loss:"0.60496, "train acc: "0.57452
# 23: "train loss:"0.58597, "train acc: "0.75481
# 23: "train loss:"0.62015, "train acc: "0.53846
# 23: "train loss:"0.62469, "train acc: "0.59375
# 23: "train loss:"0.42255, "train acc: "0.88221
# 23: "train loss:"0.52196, "train acc: "0.51442
# 23: "train loss:"0.39424, "train acc: "0.86538
# 23: "train loss:"0.43282, "train acc: "0.84375
# 23: "train loss:"0.63999, "train acc: "0.65865
# 23: "train loss:"0.56096, "train acc: "0.84135
# 23: "train loss:"0.48807, "train acc: "0.52885
# 23: "train loss:"0.59938, "train acc: "0.50962
# 23: "train loss:"0.56998, "train acc: "0.53606
# 23: "train loss:"0.64570, "train acc: "0.63221
# 23: "train loss:"0.48270, "train acc: "0.51683
# 23: "train loss:"0.36708, "train acc: "0.57452
# 23: "train loss:"0.65997, "train acc: "0.63462
# 23: "train loss:"0.53602, "train acc: "0.83894
# 23: "train loss:"0.30514, "train acc: "0.56250
# 23: "train loss:"0.62345, "train acc: "0.66346
# 23: "train loss:"0.37726, "train acc: "0.51683
# 23: "train loss:"0.51819, "train acc: "0.81971
# 23: "train loss:"0.31298, "train acc: "0.88462
# 23: "train loss:"0.50745, "train acc: "0.82692
# 23: "train loss:"0.52988, "train acc: "0.56731
# 23: "train loss:"0.51829, "train acc: "0.83894
# 23: "train loss:"0.32693, "train acc: "0.88702
# 23: "train loss:"0.62093, "train acc: "0.53846
# 23: "train loss:"0.62400, "train acc: "0.60096
# 23: "train loss:"0.41253, "train acc: "0.50481
# 23: "train loss:"0.45463, "train acc: "0.87019
# 23: "train loss:"0.34396, "train acc: "0.87981
# 23: "train loss:"0.44286, "train acc: "0.86298
# 23: "train loss:"0.47962, "train acc: "0.86058
# 23: "train loss:"0.30937, "train acc: "0.50481
# 23: "train loss:"0.58818, "train acc: "0.70913
# 23: "train loss:"0.37879, "train acc: "0.91346
# 23: "train loss:"0.54240, "train acc: "0.57692
# 23: "train loss:"0.58486, "train acc: "0.75721
# 23: "train loss:"0.57769, "train acc: "0.51442
# 23: "train loss:"0.42966, "train acc: "0.90865
# 23: "train loss:"0.58021, "train acc: "0.53365
# 23: "train loss:"0.66588, "train acc: "0.58654
# 23: "train loss:"0.32986, "train acc: "0.54567
# 23: "train loss:"0.57181, "train acc: "0.80529
# 23: "train loss:"0.36483, "train acc: "0.88702
# 23: "train loss:"0.62352, "train acc: "0.59135
# 23: "train loss:"0.41166, "train acc: "0.49519
# 23: "train loss:"0.58630, "train acc: "0.76683
# 23: "train loss:"0.40330, "train acc: "0.52163
# 23: "train loss:"0.53322, "train acc: "0.83894
# 23: "train loss:"0.22662, "train acc: "0.55769
# 23: "train loss:"0.54135, "train acc: "0.55048
# 23: "train loss:"0.41890, "train acc: "0.50000
# 23: "train loss:"0.63256, "train acc: "0.57212
# 23: "train loss:"0.64982, "train acc: "0.67308
# 23: "train loss:"0.43483, "train acc: "0.88702
# 23: "train loss:"0.33788, "train acc: "0.48558
# 23: "train loss:"0.64234, "train acc: "0.61779
# 23: "train loss:"0.63578, "train acc: "0.69712
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-1e388ce488d4> in <module>()
#      29
#      30         loss.backward()
# ---> 31         optimizer.step()
#      32
#      33         if (i+1) % 10 == 0:
#
# /usr/local/lib/python3.7/dist-packages/torch/optim/lr_scheduler.py in wrapper(*args, **kwargs)
#      63                 instance._step_count += 1
#      64                 wrapped = func.__get__(instance, cls)
# ---> 65                 return wrapped(*args, **kwargs)
#      66
#      67             # Note that the returned function here is no longer a bound method,
#
# /usr/local/lib/python3.7/dist-packages/torch/optim/optimizer.py in wrapper(*args, **kwargs)
#      86                 profile_name = "Optimizer.step#{}.step".format(obj.__class__.__name__)
#      87                 with torch.autograd.profiler.record_function(profile_name):
# ---> 88                     return func(*args, **kwargs)
#      89             return wrapper
#      90
#
# /usr/local/lib/python3.7/dist-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      25         def decorate_context(*args, **kwargs):
#      26             with self.clone():
# ---> 27                 return func(*args, **kwargs)
#      28         return cast(F, decorate_context)
#      29
#
# /usr/local/lib/python3.7/dist-packages/torch/optim/adamw.py in step(self, closure)
#     155                     weight_decay=group['weight_decay'],
#     156                     eps=group['eps'],
# --> 157                     maximize=group['maximize'])
#     158
#     159         return loss
#
# /usr/local/lib/python3.7/dist-packages/torch/optim/_functional.py in adamw(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     153         step_size = lr / bias_correction1
#     154
# --> 155         param.addcdiv_(exp_avg, denom, value=-step_size)
#     156
#     157
#
# KeyboardInterrupt:

# %% [markdown]
# # 기록
# 1번
# lr=1e-3
#
# 1.   optimizer : Adam
# 2.   scheduler : CosineAnnealingLR
# 3.   criterition:MultiLabelSoftMarginLoss
#
#
# ```
# 9: "val loss:"0.57146, "val acc: "0.67067
# 9: "val loss:"0.56269, "val acc: "0.67788
# 9: "val loss:"0.56572, "val acc: "0.67308
# 9: "val loss:"0.57164, "val acc: "0.66827
# 9: "val loss:"0.54050, "val acc: "0.73077
# 9: "val loss:"0.56166, "val acc: "0.66106
# 9: "val loss:"0.53295, "val acc: "0.68990
# 9: "val loss:"0.55628, "val acc: "0.68990
# 9: "val loss:"0.52732, "val acc: "0.71394
# ```
#
# 2번
# 1번과 같지만 모델이 efficientnet_b5 훨씬 효능이 좋다.
#
# ```
# 8: "val loss:"0.35732, "val acc: "0.83654
# 8: "val loss:"0.40119, "val acc: "0.81250
# 8: "val loss:"0.44620, "val acc: "0.77885
# 8: "val loss:"0.38490, "val acc: "0.83173
# 8: "val loss:"0.45323, "val acc: "0.81250
# 8: "val loss:"0.48173, "val acc: "0.81731
# 8: "val loss:"0.41693, "val acc: "0.81250
# 8: "val loss:"0.36138, "val acc: "0.85577
# 8: "val loss:"0.32753, "val acc: "0.85096
# 8: "val loss:"0.39352, "val acc: "0.84615
# 8: "val loss:"0.41519, "val acc: "0.81731
# 8: "val loss:"0.39349, "val acc: "0.80769
# 8: "val loss:"0.40276, "val acc: "0.82692
# 8: "val loss:"0.40279, "val acc: "0.80288
# 8: "val loss:"0.38277, "val acc: "0.82692
# 8: "val loss:"0.35343, "val acc: "0.85577
# ```
