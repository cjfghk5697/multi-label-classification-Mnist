# %% [markdown]
# <a href="https://colab.research.google.com/github/cjfghk5697/multi-label-classification-Mnist/blob/main/change.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. 이진화 코드 추가
#  이진화란 이미지를 흰색과 검은색으로 바꾼다고 생각하면 된다.
# 속도가 향상되고 정확도도 미약하지만 향상된것을 볼수 있다.
#
#  [Dacon 적용 예시](https://dacon.io/competitions/official/235697/codeshare/2436?page=2&dtype=recent)
#
#
#  [이진화 설명](https://gmnam.tistory.com/263)
#
#  <hr>
#
#  # 2. train, valid set 나누기
# ```
# train_dataset, valid_dataset = torch.utils.data.random_split(trainset, [train_size, valid_size])
#
# train_loader = DataLoader(train_dataset, batch_size=64, num_workers=8)
# valid_loader = DataLoader(valid_dataset, batch_size=64, num_workers=8)
# ```
# 처음에는 나누어지지 않아있는 코드였단 걸 발견하고 random_split 함수를 이용해 나눔. 그리고 학습 부분에서 valid 데이터를 enumerate하는 구문추가해서 valid 확인.
#
# <hr>
#
# # 3. Multi Sample Dropout 구현
#
# [자료](https://velog.io/@sujeongim/%EC%83%88%EB%A1%9C-%EB%B0%B0%EC%9A%B4-%EC%BD%94%EB%93%9C-%EC%A1%B0%EA%B0%81-Multi-Sample-Dropout)
# 단순 dropout 기법을 안썼다. 근데 큰효과가 있는지는 잘 모르지만 overfitting의 위협도 없앨겸 선택했다.
#
# <hr>
#
# # 4. Scheduler 추가
# 일단 간단하게 StepLR scheduler을 추가했다.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#%cd /content/drive/MyDrive/Test image2

#!unzip -qq "/content/drive/MyDrive/test_dirty_mnist_2nd.zip"

# %cd /content/drive/MyDrive/Train image2
# !unzip -qq "/content/drive/MyDrive/dirty_mnist_2nd.zip"
# Out:
# /content/drive/MyDrive/Train image2

# %%
# !pip3 install torchinfo
# !pip3 install cv2
# Out:
# Requirement already satisfied: torchinfo in /usr/local/lib/python3.7/dist-packages (1.6.5)
# ERROR: Could not find a version that satisfies the requirement cv2 (from versions: none)
# ERROR: No matching distribution found for cv2

# %%
import os
from typing import Tuple, Sequence, Callable
import csv
import cv2
import numpy as np
import pandas as pd
from PIL import Image
import torch
import torch.optim as optim
from torch import nn, Tensor
from torch.utils.data import Dataset, DataLoader
from torchinfo import summary
from PIL import Image
from torchvision import transforms
from torchvision.models import resnet50
#이진화 추가
import cv2
from PIL import Image

# %% [markdown]
# ## 1. 커스텀 데이터셋 만들기

# %%
class MnistDataset(Dataset):
    def __init__(
        self,
        dir: os.PathLike,
        image_ids: os.PathLike,
        transforms: Sequence[Callable]
    ) -> None:
        self.dir = dir
        self.transforms = transforms

        self.labels = {}
        with open(image_ids, 'r') as f:
            reader = csv.reader(f)
            next(reader)
            for row in reader:
                self.labels[int(row[0])] = list(map(int, row[1:]))

        self.image_ids = list(self.labels.keys())

    def __len__(self) -> int:
        return len(self.image_ids)

    def __getitem__(self, index: int) -> Tuple[Tensor]:
        image_id = self.image_ids[index]
        image = Image.open(
            os.path.join(
                self.dir, f'{str(image_id).zfill(5)}.png')).convert('RGB')
        target = np.array(self.labels.get(image_id)).astype(np.float32)


        image = np.array(image)
#이진화 완료 cv2 툴을 써서 threshold로 254 값으로 변환. cv2는 넘파이만 사용 가능해서 넘파이로 변환후 fromarry로 pil로 바꾼다.
        image_th = cv2.threshold(image,254,255,0)[1]
        image_th = Image.fromarray(image_th) # NumPy array to PIL image
        if self.transforms is not None:
            image = self.transforms(image)

        return image, target

# %% [markdown]
# ## 2. 이미지 어그멘테이션

# %%
transforms_train = transforms.Compose([
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomVerticalFlip(p=0.5),
    transforms.ToTensor(),
    transforms.Normalize(
        [0.485, 0.456, 0.406],
        [0.229, 0.224, 0.225]
    )
])

transforms_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(
        [0.485, 0.456, 0.406],
        [0.229, 0.224, 0.225]
    )
])

# %%
trainset = MnistDataset('/content/drive/MyDrive/Train image2', '/content/drive/MyDrive/dirty_mnist_2nd_answer.csv', transforms_train)
testset = MnistDataset('/content/drive/MyDrive/Test image2', '/content/drive/MyDrive/sample_submission.csv', transforms_test)

train_size = int(0.8 * len(trainset))
valid_size = len(trainset) - train_size

train_dataset, valid_dataset = torch.utils.data.random_split(trainset, [train_size, valid_size])

train_loader = DataLoader(train_dataset, batch_size=32, num_workers=8)
valid_loader = DataLoader(valid_dataset, batch_size=16, num_workers=8)

test_loader = DataLoader(testset, batch_size=32, num_workers=4)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %% [markdown]
# ## 3. ResNet50 모형

# %%
class MnistModel(nn.Module):
    def __init__(self) -> None:
        super().__init__()
        self.resnet = resnet50(pretrained=True)
        self.classifier = nn.Linear(1000, 26)
         # dropout samples 생성 
        self.dropouts = nn.ModuleList([
            nn.Dropout(0.5) for _ in range(5)
        ])

    def forward(self, x):
        x = self.resnet(x)

#multi sample Dropout 구현. 
        for i,dropout in enumerate(self.dropouts):
            if i== 0:
                out = dropout(x.clone())
                out = self.classifier(out)
            else:
                temp_out = dropout(x.clone())
                out += self.classifier(temp_out)
        return torch.sigmoid(out/len(self.dropouts))
        x = self.classifier(x)

        return x

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = MnistModel().to(device)
print(summary(model, input_size=(1, 3, 256, 256), verbose=0))
# Out:
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# MnistModel                                    --                        --
# ├─ModuleList: 1-1                             --                        --
# ├─ResNet: 1-2                                 [1, 1000]                 --
# │    └─Conv2d: 2-1                            [1, 64, 128, 128]         9,408
# │    └─BatchNorm2d: 2-2                       [1, 64, 128, 128]         128
# │    └─ReLU: 2-3                              [1, 64, 128, 128]         --
# │    └─MaxPool2d: 2-4                         [1, 64, 64, 64]           --
# │    └─Sequential: 2-5                        [1, 256, 64, 64]          --
# │    │    └─Bottleneck: 3-1                   [1, 256, 64, 64]          75,008
# │    │    └─Bottleneck: 3-2                   [1, 256, 64, 64]          70,400
# │    │    └─Bottleneck: 3-3                   [1, 256, 64, 64]          70,400
# │    └─Sequential: 2-6                        [1, 512, 32, 32]          --
# │    │    └─Bottleneck: 3-4                   [1, 512, 32, 32]          379,392
# │    │    └─Bottleneck: 3-5                   [1, 512, 32, 32]          280,064
# │    │    └─Bottleneck: 3-6                   [1, 512, 32, 32]          280,064
# │    │    └─Bottleneck: 3-7                   [1, 512, 32, 32]          280,064
# │    └─Sequential: 2-7                        [1, 1024, 16, 16]         --
# │    │    └─Bottleneck: 3-8                   [1, 1024, 16, 16]         1,512,448
# │    │    └─Bottleneck: 3-9                   [1, 1024, 16, 16]         1,117,184
# │    │    └─Bottleneck: 3-10                  [1, 1024, 16, 16]         1,117,184
# │    │    └─Bottleneck: 3-11                  [1, 1024, 16, 16]         1,117,184
# │    │    └─Bottleneck: 3-12                  [1, 1024, 16, 16]         1,117,184
# │    │    └─Bottleneck: 3-13                  [1, 1024, 16, 16]         1,117,184
# ├─ModuleList: 1-3                             --                        --
# │    └─Dropout: 2-8                           --                        --
# │    └─Dropout: 2-9                           --                        --
# │    └─Dropout: 2-10                          --                        --
# │    └─Dropout: 2-11                          --                        --
# │    └─Dropout: 2-12                          --                        --
# ├─ResNet: 1                                   --                        --
# │    └─Sequential: 2-13                       [1, 2048, 8, 8]           --
# │    │    └─Bottleneck: 3-14                  [1, 2048, 8, 8]           6,039,552
# │    │    └─Bottleneck: 3-15                  [1, 2048, 8, 8]           4,462,592
# │    │    └─Bottleneck: 3-16                  [1, 2048, 8, 8]           4,462,592
# │    └─AdaptiveAvgPool2d: 2-14                [1, 2048, 1, 1]           --
# │    └─Linear: 2-15                           [1, 1000]                 2,049,000
# ├─Linear: 1-4                                 [1, 26]                   26,026
# ===============================================================================================
# Total params: 25,583,058
# Trainable params: 25,583,058
# Non-trainable params: 0
# Total mult-adds (G): 5.34
# ===============================================================================================
# Input size (MB): 0.79
# Forward/backward pass size (MB): 232.27
# Params size (MB): 102.33
# Estimated Total Size (MB): 335.39
# ===============================================================================================

# %% [markdown]
# ## 4. 학습하기

# %%
optimizer = optim.Adam(model.parameters(), lr=1e-3)
criterion = nn.MultiLabelSoftMarginLoss()
    #scheduler 추가 및 step 추가

lr_scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=10, eta_min=0)   
num_epochs = 10
model.train()

for epoch in range(num_epochs):
    train_acc_list = []
    valid_acc_list =[]
    for i, (images, targets) in enumerate(train_loader):
        optimizer.zero_grad()

        images = images.to(device)
        targets = targets.to(device)

        outputs = model(images)
        loss = criterion(outputs, targets)

        loss.backward()
        optimizer.step()

        if (i+1) % 10 == 0:
            outputs = outputs > 0.5
            acc = (outputs == targets).float().mean()
            train_acc_list.append(acc)

            print(f'{epoch}: "train loss:"{loss.item():.5f}, "train acc: "{acc.item():.5f}')
    for i, (images, targets) in enumerate(valid_loader):
        optimizer.zero_grad()

        images = images.to(device)
        targets = targets.to(device)

        outputs = model(images)
        valid_loss = criterion(outputs, targets)
      
        if (i+1) % 10 == 0:
            outputs = outputs > 0.5
            valid_acc = (outputs == targets).float().mean()
            valid_acc_list.append(acc)

            print(f'{epoch}: "val loss:"{valid_loss.item():.5f}, "val acc: "{valid_acc.item():.5f}')
    lr_scheduler.step()
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# 0: "train loss:"0.68539, "train acc: "0.56370
# 0: "train loss:"0.69476, "train acc: "0.52284
# 0: "train loss:"0.69271, "train acc: "0.53365
# 0: "train loss:"0.69187, "train acc: "0.54688
# 0: "train loss:"0.69008, "train acc: "0.55649
# 0: "train loss:"0.69579, "train acc: "0.52644
# 0: "train loss:"0.69086, "train acc: "0.53005
# 0: "train loss:"0.70200, "train acc: "0.53125
# 0: "train loss:"0.69083, "train acc: "0.54688
# 0: "train loss:"0.69403, "train acc: "0.53005
# 0: "train loss:"0.68764, "train acc: "0.55048
# 0: "train loss:"0.69065, "train acc: "0.53365
# 0: "train loss:"0.69033, "train acc: "0.54567
# 0: "train loss:"0.69355, "train acc: "0.53486
# 0: "train loss:"0.69128, "train acc: "0.54207
# 0: "train loss:"0.69185, "train acc: "0.53606
# 0: "train loss:"0.68557, "train acc: "0.54087
# 0: "train loss:"0.69631, "train acc: "0.54447
# 0: "train loss:"0.69599, "train acc: "0.53005
# 0: "train loss:"0.68932, "train acc: "0.53966
# 0: "train loss:"0.69589, "train acc: "0.54928
# 0: "train loss:"0.69109, "train acc: "0.54207
# 0: "train loss:"0.69543, "train acc: "0.53966
# 0: "train loss:"0.69142, "train acc: "0.53726
# 0: "train loss:"0.68692, "train acc: "0.53846
# 0: "train loss:"0.68881, "train acc: "0.54928
# 0: "train loss:"0.68698, "train acc: "0.54447
# 0: "train loss:"0.68866, "train acc: "0.53486
# 0: "train loss:"0.69003, "train acc: "0.53846
# 0: "train loss:"0.69163, "train acc: "0.53245
# 0: "train loss:"0.69828, "train acc: "0.52163
# 0: "train loss:"0.68957, "train acc: "0.54087
# 0: "train loss:"0.68940, "train acc: "0.53966
# 0: "train loss:"0.68926, "train acc: "0.55409
# 0: "train loss:"0.69312, "train acc: "0.53365
# 0: "train loss:"0.68871, "train acc: "0.53846
# 0: "train loss:"0.69436, "train acc: "0.51202
# 0: "train loss:"0.69128, "train acc: "0.53966
# 0: "train loss:"0.69017, "train acc: "0.53365
# 0: "train loss:"0.69202, "train acc: "0.53245
# 0: "train loss:"0.69421, "train acc: "0.53245
# 0: "train loss:"0.69438, "train acc: "0.53005
# 0: "train loss:"0.68660, "train acc: "0.55409
# 0: "train loss:"0.68712, "train acc: "0.57091
# 0: "train loss:"0.69297, "train acc: "0.54087
# 0: "train loss:"0.69196, "train acc: "0.53486
# 0: "train loss:"0.68985, "train acc: "0.53966
# 0: "train loss:"0.69131, "train acc: "0.55048
# 0: "train loss:"0.69234, "train acc: "0.53245
# 0: "train loss:"0.69285, "train acc: "0.53125
# 0: "train loss:"0.69031, "train acc: "0.53726
# 0: "train loss:"0.69390, "train acc: "0.54327
# 0: "train loss:"0.69065, "train acc: "0.53726
# 0: "train loss:"0.69143, "train acc: "0.53606
# 0: "train loss:"0.69233, "train acc: "0.54447
# 0: "train loss:"0.69034, "train acc: "0.53726
# 0: "train loss:"0.68884, "train acc: "0.54688
# 0: "train loss:"0.68915, "train acc: "0.53846
# 0: "train loss:"0.68891, "train acc: "0.54447
# 0: "train loss:"0.68857, "train acc: "0.55409
# 0: "train loss:"0.68943, "train acc: "0.55529
# 0: "train loss:"0.69051, "train acc: "0.54207
# 0: "train loss:"0.68913, "train acc: "0.53005
# 0: "train loss:"0.69249, "train acc: "0.55529
# 0: "train loss:"0.69454, "train acc: "0.54688
# 0: "train loss:"0.69486, "train acc: "0.53486
# 0: "train loss:"0.69457, "train acc: "0.53365
# 0: "train loss:"0.70125, "train acc: "0.54688
# 0: "train loss:"0.68931, "train acc: "0.53846
# 0: "train loss:"0.69392, "train acc: "0.54327
# 0: "train loss:"0.69175, "train acc: "0.53245
# 0: "train loss:"0.69399, "train acc: "0.53125
# 0: "train loss:"0.68833, "train acc: "0.53846
# 0: "train loss:"0.69442, "train acc: "0.52284
# 0: "train loss:"0.69363, "train acc: "0.52284
# 0: "train loss:"0.69230, "train acc: "0.54928
# 0: "train loss:"0.69111, "train acc: "0.55048
# 0: "train loss:"0.69549, "train acc: "0.53005
# 0: "train loss:"0.69399, "train acc: "0.54447
# 0: "train loss:"0.69382, "train acc: "0.54688
# 0: "train loss:"0.69357, "train acc: "0.54087
# 0: "train loss:"0.69889, "train acc: "0.53005
# 0: "train loss:"0.69281, "train acc: "0.53245
# 0: "train loss:"0.69272, "train acc: "0.53606
# 0: "train loss:"0.69081, "train acc: "0.53726
# 0: "train loss:"0.69140, "train acc: "0.54928
# 0: "train loss:"0.69491, "train acc: "0.52043
# 0: "train loss:"0.68999, "train acc: "0.54087
# 0: "train loss:"0.69250, "train acc: "0.53245
# 0: "train loss:"0.68984, "train acc: "0.53486
# 0: "train loss:"0.69081, "train acc: "0.55889
# 0: "train loss:"0.69051, "train acc: "0.54087
# 0: "train loss:"0.69324, "train acc: "0.54447
# 0: "train loss:"0.68756, "train acc: "0.54808
# 0: "train loss:"0.69217, "train acc: "0.53125
# 0: "train loss:"0.68753, "train acc: "0.54087
# 0: "train loss:"0.68948, "train acc: "0.55288
# 0: "train loss:"0.68962, "train acc: "0.55168
# 0: "train loss:"0.68804, "train acc: "0.55288
# 0: "train loss:"0.69252, "train acc: "0.54087
# 0: "train loss:"0.69870, "train acc: "0.52404
# 0: "train loss:"0.69222, "train acc: "0.53606
# 0: "train loss:"0.69327, "train acc: "0.53365
# 0: "train loss:"0.69412, "train acc: "0.53245
# 0: "train loss:"0.69245, "train acc: "0.53005
# 0: "train loss:"0.69097, "train acc: "0.54928
# 0: "train loss:"0.69111, "train acc: "0.54688
# 0: "train loss:"0.69923, "train acc: "0.53005
# 0: "train loss:"0.69294, "train acc: "0.53966
# 0: "train loss:"0.68977, "train acc: "0.55048
# 0: "train loss:"0.68501, "train acc: "0.54327
# 0: "train loss:"0.69178, "train acc: "0.54688
# 0: "train loss:"0.69619, "train acc: "0.53245
# 0: "train loss:"0.69420, "train acc: "0.53245
# 0: "train loss:"0.69862, "train acc: "0.53245
# 0: "train loss:"0.69154, "train acc: "0.53365
# 0: "train loss:"0.69183, "train acc: "0.55409
# 0: "train loss:"0.69319, "train acc: "0.52284
# 0: "train loss:"0.69366, "train acc: "0.53365
# 0: "train loss:"0.69349, "train acc: "0.54087
# 0: "train loss:"0.70362, "train acc: "0.53486
# 0: "train loss:"0.68930, "train acc: "0.54688
# 0: "train loss:"0.69277, "train acc: "0.53125
# 0: "train loss:"0.69248, "train acc: "0.53966
# 0: "train loss:"0.69216, "train acc: "0.55168
# 0: "val loss:"0.69439, "val acc: "0.53846
# 0: "val loss:"0.69073, "val acc: "0.55048
# 0: "val loss:"0.69041, "val acc: "0.53125
# 0: "val loss:"0.68784, "val acc: "0.54808
# 0: "val loss:"0.68902, "val acc: "0.52644
# 0: "val loss:"0.69183, "val acc: "0.54087
# 0: "val loss:"0.69560, "val acc: "0.54567
# 0: "val loss:"0.68779, "val acc: "0.56971
# 0: "val loss:"0.69918, "val acc: "0.53125
# 0: "val loss:"0.69473, "val acc: "0.51683
# 0: "val loss:"0.69473, "val acc: "0.54808
# 0: "val loss:"0.69841, "val acc: "0.51442
# 0: "val loss:"0.68672, "val acc: "0.56010
# 0: "val loss:"0.69626, "val acc: "0.54567
# 0: "val loss:"0.69960, "val acc: "0.52163
# 0: "val loss:"0.69943, "val acc: "0.53846
# 0: "val loss:"0.69744, "val acc: "0.51442
# 0: "val loss:"0.69164, "val acc: "0.54567
# 0: "val loss:"0.69527, "val acc: "0.53846
# 0: "val loss:"0.69608, "val acc: "0.53365
# 0: "val loss:"0.70268, "val acc: "0.52404
# 0: "val loss:"0.68910, "val acc: "0.54327
# 0: "val loss:"0.69194, "val acc: "0.51923
# 0: "val loss:"0.69812, "val acc: "0.53606
# 0: "val loss:"0.69294, "val acc: "0.54087
# 0: "val loss:"0.69877, "val acc: "0.51202
# 0: "val loss:"0.69376, "val acc: "0.54808
# 0: "val loss:"0.68911, "val acc: "0.52404
# 0: "val loss:"0.69282, "val acc: "0.55529
# 0: "val loss:"0.69118, "val acc: "0.55288
# 0: "val loss:"0.69376, "val acc: "0.54808
# 0: "val loss:"0.69030, "val acc: "0.54087
# 0: "val loss:"0.69322, "val acc: "0.51442
# 0: "val loss:"0.69509, "val acc: "0.52163
# 0: "val loss:"0.69194, "val acc: "0.52404
# 0: "val loss:"0.69557, "val acc: "0.53846
# 0: "val loss:"0.69031, "val acc: "0.54087
# 0: "val loss:"0.69179, "val acc: "0.55048
# 0: "val loss:"0.69169, "val acc: "0.54327
# 0: "val loss:"0.69585, "val acc: "0.52885
# 0: "val loss:"0.69372, "val acc: "0.54327
# 0: "val loss:"0.70318, "val acc: "0.52644
# 0: "val loss:"0.69798, "val acc: "0.53365
# 0: "val loss:"0.69566, "val acc: "0.53846
# 0: "val loss:"0.68386, "val acc: "0.54808
# 0: "val loss:"0.70312, "val acc: "0.50962
# 0: "val loss:"0.69825, "val acc: "0.50962
# 0: "val loss:"0.69166, "val acc: "0.54327
# 0: "val loss:"0.69305, "val acc: "0.54567
# 0: "val loss:"0.69722, "val acc: "0.55048
# 0: "val loss:"0.69542, "val acc: "0.55048
# 0: "val loss:"0.69906, "val acc: "0.52644
# 0: "val loss:"0.69248, "val acc: "0.53846
# 0: "val loss:"0.67667, "val acc: "0.54327
# 0: "val loss:"0.69325, "val acc: "0.54567
# 0: "val loss:"0.69771, "val acc: "0.54327
# 0: "val loss:"0.69596, "val acc: "0.51683
# 0: "val loss:"0.69752, "val acc: "0.54327
# 0: "val loss:"0.69594, "val acc: "0.54087
# 0: "val loss:"0.69400, "val acc: "0.52885
# 0: "val loss:"0.69762, "val acc: "0.51683
# 0: "val loss:"0.69414, "val acc: "0.55288
# 1: "train loss:"0.68241, "train acc: "0.56370
# 1: "train loss:"0.69454, "train acc: "0.52284
# 1: "train loss:"0.69186, "train acc: "0.53365
# 1: "train loss:"0.69269, "train acc: "0.54567
# 1: "train loss:"0.68939, "train acc: "0.55649
# 1: "train loss:"0.69588, "train acc: "0.52644
# 1: "train loss:"0.69228, "train acc: "0.53005
# 1: "train loss:"0.70334, "train acc: "0.53125
# 1: "train loss:"0.69046, "train acc: "0.54688
# 1: "train loss:"0.69292, "train acc: "0.53005
# 1: "train loss:"0.68509, "train acc: "0.55048
# 1: "train loss:"0.69647, "train acc: "0.53365
# 1: "train loss:"0.68853, "train acc: "0.54567
# 1: "train loss:"0.69220, "train acc: "0.53486
# 1: "train loss:"0.69230, "train acc: "0.54207
# 1: "train loss:"0.69145, "train acc: "0.53606
# 1: "train loss:"0.68603, "train acc: "0.54087
# 1: "train loss:"0.69259, "train acc: "0.54447
# 1: "train loss:"0.69291, "train acc: "0.53005
# 1: "train loss:"0.68893, "train acc: "0.53966
# 1: "train loss:"0.69078, "train acc: "0.54928
# 1: "train loss:"0.69340, "train acc: "0.54207
# 1: "train loss:"0.68913, "train acc: "0.53966
# 1: "train loss:"0.69211, "train acc: "0.53726
# 1: "train loss:"0.68929, "train acc: "0.53846
# 1: "train loss:"0.68845, "train acc: "0.54928
# 1: "train loss:"0.68858, "train acc: "0.54447
# 1: "train loss:"0.69083, "train acc: "0.53486
# 1: "train loss:"0.69220, "train acc: "0.53846
# 1: "train loss:"0.69181, "train acc: "0.53245
# 1: "train loss:"0.69771, "train acc: "0.52163
# 1: "train loss:"0.69049, "train acc: "0.54087
# 1: "train loss:"0.68988, "train acc: "0.53966
# 1: "train loss:"0.68931, "train acc: "0.55409
# 1: "train loss:"0.69370, "train acc: "0.53365
# 1: "train loss:"0.68989, "train acc: "0.53846
# 1: "train loss:"0.69655, "train acc: "0.51202
# 1: "train loss:"0.69192, "train acc: "0.53966
# 1: "train loss:"0.69201, "train acc: "0.53365
# 1: "train loss:"0.69329, "train acc: "0.53245
# 1: "train loss:"0.69233, "train acc: "0.53245
# 1: "train loss:"0.69322, "train acc: "0.53005
# 1: "train loss:"0.68733, "train acc: "0.55409
# 1: "train loss:"0.68642, "train acc: "0.57091
# 1: "train loss:"0.69389, "train acc: "0.54087
# 1: "train loss:"0.69250, "train acc: "0.53486
# 1: "train loss:"0.69270, "train acc: "0.53966
# 1: "train loss:"0.69159, "train acc: "0.55048
# 1: "train loss:"0.69332, "train acc: "0.53245
# 1: "train loss:"0.69334, "train acc: "0.53125
# 1: "train loss:"0.69112, "train acc: "0.53726
# 1: "train loss:"0.69003, "train acc: "0.54327
# 1: "train loss:"0.69221, "train acc: "0.53726
# 1: "train loss:"0.69017, "train acc: "0.53606
# 1: "train loss:"0.69121, "train acc: "0.54447
# 1: "train loss:"0.69155, "train acc: "0.53726
# 1: "train loss:"0.69109, "train acc: "0.54688
# 1: "train loss:"0.68859, "train acc: "0.53846
# 1: "train loss:"0.68834, "train acc: "0.54447
# 1: "train loss:"0.68787, "train acc: "0.55409
# 1: "train loss:"0.68759, "train acc: "0.55529
# 1: "train loss:"0.68888, "train acc: "0.54207
# 1: "train loss:"0.69149, "train acc: "0.53005
# 1: "train loss:"0.69229, "train acc: "0.55529
# 1: "train loss:"0.69141, "train acc: "0.54808
# 1: "train loss:"0.69084, "train acc: "0.53726
# 1: "train loss:"0.68914, "train acc: "0.53365
# 1: "train loss:"0.69175, "train acc: "0.54688
# 1: "train loss:"0.69174, "train acc: "0.53846
# 1: "train loss:"0.69141, "train acc: "0.54327
# 1: "train loss:"0.69183, "train acc: "0.53245
# 1: "train loss:"0.69326, "train acc: "0.53125
# 1: "train loss:"0.69152, "train acc: "0.53846
# 1: "train loss:"0.69355, "train acc: "0.52284
# 1: "train loss:"0.69352, "train acc: "0.52284
# 1: "train loss:"0.69231, "train acc: "0.54928
# 1: "train loss:"0.68903, "train acc: "0.55048
# 1: "train loss:"0.69614, "train acc: "0.53005
# 1: "train loss:"0.69337, "train acc: "0.54447
# 1: "train loss:"0.68892, "train acc: "0.54688
# 1: "train loss:"0.68891, "train acc: "0.54087
# 1: "train loss:"0.69724, "train acc: "0.53005
# 1: "train loss:"0.69205, "train acc: "0.53245
# 1: "train loss:"0.69209, "train acc: "0.53606
# 1: "train loss:"0.69072, "train acc: "0.53726
# 1: "train loss:"0.69170, "train acc: "0.54928
# 1: "train loss:"0.69480, "train acc: "0.52043
# 1: "train loss:"0.69019, "train acc: "0.54087
# 1: "train loss:"0.69214, "train acc: "0.53245
# 1: "train loss:"0.69155, "train acc: "0.53486
# 1: "train loss:"0.68984, "train acc: "0.55889
# 1: "train loss:"0.69053, "train acc: "0.54087
# 1: "train loss:"0.69347, "train acc: "0.54447
# 1: "train loss:"0.68723, "train acc: "0.54808
# 1: "train loss:"0.69144, "train acc: "0.53125
# 1: "train loss:"0.68811, "train acc: "0.54087
# 1: "train loss:"0.68909, "train acc: "0.55288
# 1: "train loss:"0.69054, "train acc: "0.55168
# 1: "train loss:"0.68882, "train acc: "0.55288
# 1: "train loss:"0.69257, "train acc: "0.54087
# 1: "train loss:"0.69935, "train acc: "0.52404
# 1: "train loss:"0.69391, "train acc: "0.53606
# 1: "train loss:"0.69502, "train acc: "0.53365
# 1: "train loss:"0.69441, "train acc: "0.53245
# 1: "train loss:"0.69057, "train acc: "0.53005
# 1: "train loss:"0.69184, "train acc: "0.54928
# 1: "train loss:"0.69148, "train acc: "0.54688
# 1: "train loss:"0.70117, "train acc: "0.53005
# 1: "train loss:"0.69228, "train acc: "0.53966
# 1: "train loss:"0.68891, "train acc: "0.55048
# 1: "train loss:"0.68941, "train acc: "0.54327
# 1: "train loss:"0.69204, "train acc: "0.54688
# 1: "train loss:"0.69705, "train acc: "0.53245
# 1: "train loss:"0.69537, "train acc: "0.53245
# 1: "train loss:"0.69668, "train acc: "0.53245
# 1: "train loss:"0.69458, "train acc: "0.53365
# 1: "train loss:"0.68944, "train acc: "0.55409
# 1: "train loss:"0.69337, "train acc: "0.52284
# 1: "train loss:"0.69086, "train acc: "0.53365
# 1: "train loss:"0.69720, "train acc: "0.54087
# 1: "train loss:"0.69310, "train acc: "0.53726
# 1: "train loss:"0.68811, "train acc: "0.54688
# 1: "train loss:"0.69574, "train acc: "0.53125
# 1: "train loss:"0.69537, "train acc: "0.53966
# 1: "train loss:"0.68724, "train acc: "0.55409
# 1: "val loss:"0.69588, "val acc: "0.53846
# 1: "val loss:"0.69358, "val acc: "0.55048
# 1: "val loss:"0.68990, "val acc: "0.53125
# 1: "val loss:"0.69389, "val acc: "0.54808
# 1: "val loss:"0.69154, "val acc: "0.52644
# 1: "val loss:"0.68710, "val acc: "0.54087
# 1: "val loss:"0.69118, "val acc: "0.54567
# 1: "val loss:"0.68340, "val acc: "0.56971
# 1: "val loss:"0.69273, "val acc: "0.53365
# 1: "val loss:"0.69389, "val acc: "0.51923
# 1: "val loss:"0.69378, "val acc: "0.54808
# 1: "val loss:"0.70066, "val acc: "0.51442
# 1: "val loss:"0.68845, "val acc: "0.56010
# 1: "val loss:"0.69033, "val acc: "0.54567
# 1: "val loss:"0.69234, "val acc: "0.52163
# 1: "val loss:"0.69522, "val acc: "0.53846
# 1: "val loss:"0.69560, "val acc: "0.51442
# 1: "val loss:"0.68930, "val acc: "0.54567
# 1: "val loss:"0.69311, "val acc: "0.53846
# 1: "val loss:"0.69210, "val acc: "0.53365
# 1: "val loss:"0.69566, "val acc: "0.52404
# 1: "val loss:"0.68940, "val acc: "0.54087
# 1: "val loss:"0.69258, "val acc: "0.51923
# 1: "val loss:"0.69250, "val acc: "0.53606
# 1: "val loss:"0.69334, "val acc: "0.54087
# 1: "val loss:"0.69786, "val acc: "0.51202
# 1: "val loss:"0.68983, "val acc: "0.54808
# 1: "val loss:"0.69093, "val acc: "0.52404
# 1: "val loss:"0.69075, "val acc: "0.55529
# 1: "val loss:"0.68618, "val acc: "0.55288
# 1: "val loss:"0.69048, "val acc: "0.54808
# 1: "val loss:"0.69273, "val acc: "0.54087
# 1: "val loss:"0.69253, "val acc: "0.51442
# 1: "val loss:"0.69410, "val acc: "0.52163
# 1: "val loss:"0.69019, "val acc: "0.52404
# 1: "val loss:"0.68988, "val acc: "0.53846
# 1: "val loss:"0.69116, "val acc: "0.54087
# 1: "val loss:"0.69043, "val acc: "0.55048
# 1: "val loss:"0.69078, "val acc: "0.54327
# 1: "val loss:"0.69527, "val acc: "0.52885
# 1: "val loss:"0.69122, "val acc: "0.54087
# 1: "val loss:"0.69476, "val acc: "0.52644
# 1: "val loss:"0.69729, "val acc: "0.53365
# 1: "val loss:"0.69122, "val acc: "0.53846
# 1: "val loss:"0.68649, "val acc: "0.54808
# 1: "val loss:"0.69872, "val acc: "0.50962
# 1: "val loss:"0.69523, "val acc: "0.50962
# 1: "val loss:"0.69020, "val acc: "0.54327
# 1: "val loss:"0.69219, "val acc: "0.54567
# 1: "val loss:"0.69704, "val acc: "0.55048
# 1: "val loss:"0.69326, "val acc: "0.55048
# 1: "val loss:"0.69337, "val acc: "0.52644
# 1: "val loss:"0.68778, "val acc: "0.53846
# 1: "val loss:"0.68697, "val acc: "0.54327
# 1: "val loss:"0.68774, "val acc: "0.54808
# 1: "val loss:"0.69122, "val acc: "0.54327
# 1: "val loss:"0.69248, "val acc: "0.51683
# 1: "val loss:"0.69319, "val acc: "0.54327
# 1: "val loss:"0.69391, "val acc: "0.54087
# 1: "val loss:"0.69087, "val acc: "0.52885
# 1: "val loss:"0.69666, "val acc: "0.51683
# 1: "val loss:"0.69043, "val acc: "0.55288
# 2: "train loss:"0.68250, "train acc: "0.56370
# 2: "train loss:"0.69385, "train acc: "0.52284
# 2: "train loss:"0.69299, "train acc: "0.53365
# 2: "train loss:"0.69087, "train acc: "0.54688
# 2: "train loss:"0.68868, "train acc: "0.55649
# 2: "train loss:"0.69378, "train acc: "0.52644
# 2: "train loss:"0.69082, "train acc: "0.53005
# 2: "train loss:"0.69908, "train acc: "0.53125
# 2: "train loss:"0.69146, "train acc: "0.54688
# 2: "train loss:"0.69318, "train acc: "0.53005
# 2: "train loss:"0.68601, "train acc: "0.55048
# 2: "train loss:"0.69404, "train acc: "0.53365
# 2: "train loss:"0.68871, "train acc: "0.54567
# 2: "train loss:"0.69061, "train acc: "0.53486
# 2: "train loss:"0.69460, "train acc: "0.54207
# 2: "train loss:"0.69201, "train acc: "0.53606
# 2: "train loss:"0.68664, "train acc: "0.54087
# 2: "train loss:"0.69088, "train acc: "0.54447
# 2: "train loss:"0.69523, "train acc: "0.53005
# 2: "train loss:"0.68677, "train acc: "0.53966
# 2: "train loss:"0.69407, "train acc: "0.54928
# 2: "train loss:"0.69209, "train acc: "0.54207
# 2: "train loss:"0.69120, "train acc: "0.53966
# 2: "train loss:"0.69126, "train acc: "0.53726
# 2: "train loss:"0.68949, "train acc: "0.53846
# 2: "train loss:"0.68909, "train acc: "0.54928
# 2: "train loss:"0.68788, "train acc: "0.54447
# 2: "train loss:"0.69030, "train acc: "0.53486
# 2: "train loss:"0.69354, "train acc: "0.53846
# 2: "train loss:"0.69170, "train acc: "0.53245
# 2: "train loss:"0.69937, "train acc: "0.52163
# 2: "train loss:"0.69135, "train acc: "0.54087
# 2: "train loss:"0.69000, "train acc: "0.53966
# 2: "train loss:"0.68922, "train acc: "0.55409
# 2: "train loss:"0.69352, "train acc: "0.53365
# 2: "train loss:"0.69025, "train acc: "0.53846
# 2: "train loss:"0.69925, "train acc: "0.51202
# 2: "train loss:"0.69207, "train acc: "0.53966
# 2: "train loss:"0.69222, "train acc: "0.53365
# 2: "train loss:"0.69510, "train acc: "0.53245
# 2: "train loss:"0.69206, "train acc: "0.53245
# 2: "train loss:"0.69025, "train acc: "0.53005
# 2: "train loss:"0.68787, "train acc: "0.55409
# 2: "train loss:"0.68660, "train acc: "0.57091
# 2: "train loss:"0.69118, "train acc: "0.54087
# 2: "train loss:"0.69281, "train acc: "0.53486
# 2: "train loss:"0.69019, "train acc: "0.53966
# 2: "train loss:"0.69224, "train acc: "0.55048
# 2: "train loss:"0.69159, "train acc: "0.53245
# 2: "train loss:"0.69178, "train acc: "0.53125
# 2: "train loss:"0.69106, "train acc: "0.53726
# 2: "train loss:"0.69177, "train acc: "0.54327
# 2: "train loss:"0.69083, "train acc: "0.53726
# 2: "train loss:"0.69118, "train acc: "0.53606
# 2: "train loss:"0.69200, "train acc: "0.54447
# 2: "train loss:"0.69192, "train acc: "0.53726
# 2: "train loss:"0.68967, "train acc: "0.54688
# 2: "train loss:"0.68937, "train acc: "0.53846
# 2: "train loss:"0.68696, "train acc: "0.54447
# 2: "train loss:"0.68811, "train acc: "0.55409
# 2: "train loss:"0.68753, "train acc: "0.55529
# 2: "train loss:"0.69169, "train acc: "0.54207
# 2: "train loss:"0.69234, "train acc: "0.53005
# 2: "train loss:"0.69012, "train acc: "0.55529
# 2: "train loss:"0.68832, "train acc: "0.54808
# 2: "train loss:"0.69242, "train acc: "0.53726
# 2: "train loss:"0.69038, "train acc: "0.53365
# 2: "train loss:"0.69705, "train acc: "0.54688
# 2: "train loss:"0.69289, "train acc: "0.53846
# 2: "train loss:"0.69146, "train acc: "0.54327
# 2: "train loss:"0.69126, "train acc: "0.53245
# 2: "train loss:"0.69280, "train acc: "0.53125
# 2: "train loss:"0.69173, "train acc: "0.53846
# 2: "train loss:"0.69229, "train acc: "0.52284
# 2: "train loss:"0.69217, "train acc: "0.52284
# 2: "train loss:"0.69323, "train acc: "0.54928
# 2: "train loss:"0.69070, "train acc: "0.55048
# 2: "train loss:"0.69727, "train acc: "0.53005
# 2: "train loss:"0.69169, "train acc: "0.54447
# 2: "train loss:"0.68873, "train acc: "0.54688
# 2: "train loss:"0.68909, "train acc: "0.54087
# 2: "train loss:"0.69725, "train acc: "0.53005
# 2: "train loss:"0.69069, "train acc: "0.53245
# 2: "train loss:"0.69074, "train acc: "0.53606
# 2: "train loss:"0.69033, "train acc: "0.53726
# 2: "train loss:"0.69246, "train acc: "0.54928
# 2: "train loss:"0.69447, "train acc: "0.52043
# 2: "train loss:"0.69310, "train acc: "0.54087
# 2: "train loss:"0.69255, "train acc: "0.53245
# 2: "train loss:"0.69157, "train acc: "0.53486
# 2: "train loss:"0.68868, "train acc: "0.55889
# 2: "train loss:"0.69044, "train acc: "0.54087
# 2: "train loss:"0.69396, "train acc: "0.54447
# 2: "train loss:"0.68702, "train acc: "0.54808
# 2: "train loss:"0.69046, "train acc: "0.53125
# 2: "train loss:"0.68742, "train acc: "0.54087
# 2: "train loss:"0.68976, "train acc: "0.55288
# 2: "train loss:"0.69081, "train acc: "0.55168
# 2: "train loss:"0.68858, "train acc: "0.55288
# 2: "train loss:"0.69456, "train acc: "0.54087
# 2: "train loss:"0.69957, "train acc: "0.52404
# 2: "train loss:"0.69150, "train acc: "0.53606
# 2: "train loss:"0.69384, "train acc: "0.53365
# 2: "train loss:"0.69396, "train acc: "0.53245
# 2: "train loss:"0.69056, "train acc: "0.53005
# 2: "train loss:"0.69127, "train acc: "0.54928
# 2: "train loss:"0.69201, "train acc: "0.54688
# 2: "train loss:"0.70034, "train acc: "0.53005
# 2: "train loss:"0.69195, "train acc: "0.53966
# 2: "train loss:"0.69055, "train acc: "0.55048
# 2: "train loss:"0.68534, "train acc: "0.54327
# 2: "train loss:"0.68910, "train acc: "0.54688
# 2: "train loss:"0.69523, "train acc: "0.53245
# 2: "train loss:"0.69246, "train acc: "0.53245
# 2: "train loss:"0.69988, "train acc: "0.53245
# 2: "train loss:"0.69344, "train acc: "0.53365
# 2: "train loss:"0.68997, "train acc: "0.55409
# 2: "train loss:"0.69395, "train acc: "0.52284
# 2: "train loss:"0.69086, "train acc: "0.53365
# 2: "train loss:"0.69710, "train acc: "0.54087
# 2: "train loss:"0.69306, "train acc: "0.53726
# 2: "train loss:"0.68817, "train acc: "0.54688
# 2: "train loss:"0.69440, "train acc: "0.53125
# 2: "train loss:"0.69302, "train acc: "0.53966
# 2: "train loss:"0.68937, "train acc: "0.55409
# 2: "val loss:"0.69835, "val acc: "0.53846
# 2: "val loss:"0.69236, "val acc: "0.55048
# 2: "val loss:"0.69186, "val acc: "0.53125
# 2: "val loss:"0.69566, "val acc: "0.54808
# 2: "val loss:"0.69250, "val acc: "0.52644
# 2: "val loss:"0.68868, "val acc: "0.54087
# 2: "val loss:"0.69223, "val acc: "0.54567
# 2: "val loss:"0.68208, "val acc: "0.56971
# 2: "val loss:"0.69056, "val acc: "0.53365
# 2: "val loss:"0.69637, "val acc: "0.51923
# 2: "val loss:"0.69548, "val acc: "0.54808
# 2: "val loss:"0.70356, "val acc: "0.51442
# 2: "val loss:"0.68714, "val acc: "0.56010
# 2: "val loss:"0.69197, "val acc: "0.54567
# 2: "val loss:"0.69184, "val acc: "0.52163
# 2: "val loss:"0.69781, "val acc: "0.53846
# 2: "val loss:"0.69578, "val acc: "0.51442
# 2: "val loss:"0.69190, "val acc: "0.54567
# 2: "val loss:"0.69617, "val acc: "0.53846
# 2: "val loss:"0.69427, "val acc: "0.53365
# 2: "val loss:"0.69642, "val acc: "0.52404
# 2: "val loss:"0.68669, "val acc: "0.54087
# 2: "val loss:"0.69458, "val acc: "0.51923
# 2: "val loss:"0.69323, "val acc: "0.53606
# 2: "val loss:"0.69555, "val acc: "0.54087
# 2: "val loss:"0.69855, "val acc: "0.51202
# 2: "val loss:"0.69308, "val acc: "0.54808
# 2: "val loss:"0.69327, "val acc: "0.52404
# 2: "val loss:"0.69253, "val acc: "0.55529
# 2: "val loss:"0.68503, "val acc: "0.55288
# 2: "val loss:"0.68841, "val acc: "0.54808
# 2: "val loss:"0.69138, "val acc: "0.54087
# 2: "val loss:"0.69356, "val acc: "0.51442
# 2: "val loss:"0.69437, "val acc: "0.52163
# 2: "val loss:"0.69093, "val acc: "0.52404
# 2: "val loss:"0.68971, "val acc: "0.53846
# 2: "val loss:"0.69366, "val acc: "0.54087
# 2: "val loss:"0.69244, "val acc: "0.55048
# 2: "val loss:"0.69213, "val acc: "0.54327
# 2: "val loss:"0.69871, "val acc: "0.52885
# 2: "val loss:"0.69126, "val acc: "0.54087
# 2: "val loss:"0.69735, "val acc: "0.52644
# 2: "val loss:"0.69934, "val acc: "0.53365
# 2: "val loss:"0.69246, "val acc: "0.53846
# 2: "val loss:"0.68616, "val acc: "0.54808
# 2: "val loss:"0.70284, "val acc: "0.50962
# 2: "val loss:"0.69744, "val acc: "0.50962
# 2: "val loss:"0.69201, "val acc: "0.54327
# 2: "val loss:"0.68997, "val acc: "0.54567
# 2: "val loss:"0.69830, "val acc: "0.55048
# 2: "val loss:"0.69401, "val acc: "0.55048
# 2: "val loss:"0.69410, "val acc: "0.52644
# 2: "val loss:"0.69011, "val acc: "0.53846
# 2: "val loss:"0.68798, "val acc: "0.54327
# 2: "val loss:"0.68732, "val acc: "0.54808
# 2: "val loss:"0.69207, "val acc: "0.54327
# 2: "val loss:"0.69030, "val acc: "0.51683
# 2: "val loss:"0.69451, "val acc: "0.54327
# 2: "val loss:"0.69592, "val acc: "0.54087
# 2: "val loss:"0.69042, "val acc: "0.52885
# 2: "val loss:"0.70211, "val acc: "0.51683
# 2: "val loss:"0.69340, "val acc: "0.55288
# 3: "train loss:"0.68385, "train acc: "0.56370
# 3: "train loss:"0.69539, "train acc: "0.52284
# 3: "train loss:"0.69219, "train acc: "0.53365
# 3: "train loss:"0.69001, "train acc: "0.54688
# 3: "train loss:"0.68714, "train acc: "0.55649
# 3: "train loss:"0.69258, "train acc: "0.52644
# 3: "train loss:"0.69042, "train acc: "0.53005
# 3: "train loss:"0.69939, "train acc: "0.53125
# 3: "train loss:"0.69119, "train acc: "0.54688
# 3: "train loss:"0.69454, "train acc: "0.53005
# 3: "train loss:"0.68855, "train acc: "0.55048
# 3: "train loss:"0.69274, "train acc: "0.53365
# 3: "train loss:"0.68714, "train acc: "0.54567
# 3: "train loss:"0.69090, "train acc: "0.53486
# 3: "train loss:"0.69091, "train acc: "0.54207
# 3: "train loss:"0.69105, "train acc: "0.53606
# 3: "train loss:"0.68689, "train acc: "0.54087
# 3: "train loss:"0.69236, "train acc: "0.54447
# 3: "train loss:"0.69403, "train acc: "0.53005
# 3: "train loss:"0.68758, "train acc: "0.53966
# 3: "train loss:"0.69624, "train acc: "0.54928
# 3: "train loss:"0.68922, "train acc: "0.54207
# 3: "train loss:"0.69359, "train acc: "0.53966
# 3: "train loss:"0.69077, "train acc: "0.53726
# 3: "train loss:"0.68813, "train acc: "0.53846
# 3: "train loss:"0.68736, "train acc: "0.54928
# 3: "train loss:"0.68807, "train acc: "0.54447
# 3: "train loss:"0.68972, "train acc: "0.53486
# 3: "train loss:"0.69077, "train acc: "0.53846
# 3: "train loss:"0.69185, "train acc: "0.53245
# 3: "train loss:"0.69703, "train acc: "0.52163
# 3: "train loss:"0.69000, "train acc: "0.54087
# 3: "train loss:"0.68791, "train acc: "0.53966
# 3: "train loss:"0.68987, "train acc: "0.55409
# 3: "train loss:"0.69197, "train acc: "0.53365
# 3: "train loss:"0.69070, "train acc: "0.53846
# 3: "train loss:"0.69727, "train acc: "0.51202
# 3: "train loss:"0.69279, "train acc: "0.53966
# 3: "train loss:"0.69414, "train acc: "0.53365
# 3: "train loss:"0.69346, "train acc: "0.53245
# 3: "train loss:"0.69300, "train acc: "0.53245
# 3: "train loss:"0.69175, "train acc: "0.53005
# 3: "train loss:"0.68791, "train acc: "0.55409
# 3: "train loss:"0.68576, "train acc: "0.57091
# 3: "train loss:"0.69053, "train acc: "0.54087
# 3: "train loss:"0.69225, "train acc: "0.53486
# 3: "train loss:"0.69026, "train acc: "0.53966
# 3: "train loss:"0.69300, "train acc: "0.55048
# 3: "train loss:"0.69255, "train acc: "0.53245
# 3: "train loss:"0.69443, "train acc: "0.53125
# 3: "train loss:"0.69258, "train acc: "0.53726
# 3: "train loss:"0.69224, "train acc: "0.54327
# 3: "train loss:"0.69160, "train acc: "0.53726
# 3: "train loss:"0.69048, "train acc: "0.53606
# 3: "train loss:"0.69136, "train acc: "0.54447
# 3: "train loss:"0.69115, "train acc: "0.53726
# 3: "train loss:"0.69062, "train acc: "0.54688
# 3: "train loss:"0.68848, "train acc: "0.53846
# 3: "train loss:"0.68877, "train acc: "0.54447
# 3: "train loss:"0.68748, "train acc: "0.55409
# 3: "train loss:"0.68766, "train acc: "0.55529
# 3: "train loss:"0.69364, "train acc: "0.54207
# 3: "train loss:"0.69245, "train acc: "0.53005
# 3: "train loss:"0.69149, "train acc: "0.55529
# 3: "train loss:"0.68901, "train acc: "0.54808
# 3: "train loss:"0.69186, "train acc: "0.53726
# 3: "train loss:"0.68984, "train acc: "0.53365
# 3: "train loss:"0.69283, "train acc: "0.54688
# 3: "train loss:"0.69032, "train acc: "0.53846
# 3: "train loss:"0.69247, "train acc: "0.54327
# 3: "train loss:"0.69026, "train acc: "0.53245
# 3: "train loss:"0.69363, "train acc: "0.53125
# 3: "train loss:"0.69288, "train acc: "0.53846
# 3: "train loss:"0.69261, "train acc: "0.52284
# 3: "train loss:"0.69035, "train acc: "0.52284
# 3: "train loss:"0.69444, "train acc: "0.54928
# 3: "train loss:"0.69026, "train acc: "0.55048
# 3: "train loss:"0.69550, "train acc: "0.53005
# 3: "train loss:"0.69280, "train acc: "0.54447
# 3: "train loss:"0.68665, "train acc: "0.54688
# 3: "train loss:"0.68788, "train acc: "0.54087
# 3: "train loss:"0.69370, "train acc: "0.53005
# 3: "train loss:"0.69135, "train acc: "0.53245
# 3: "train loss:"0.69138, "train acc: "0.53606
# 3: "train loss:"0.69133, "train acc: "0.53726
# 3: "train loss:"0.69042, "train acc: "0.54928
# 3: "train loss:"0.69388, "train acc: "0.52043
# 3: "train loss:"0.69235, "train acc: "0.54087
# 3: "train loss:"0.69174, "train acc: "0.53245
# 3: "train loss:"0.69181, "train acc: "0.53486
# 3: "train loss:"0.69181, "train acc: "0.55889
# 3: "train loss:"0.69027, "train acc: "0.54087
# 3: "train loss:"0.69253, "train acc: "0.54447
# 3: "train loss:"0.68655, "train acc: "0.54808
# 3: "train loss:"0.69020, "train acc: "0.53125
# 3: "train loss:"0.68778, "train acc: "0.54087
# 3: "train loss:"0.68995, "train acc: "0.55288
# 3: "train loss:"0.69062, "train acc: "0.55168
# 3: "train loss:"0.68834, "train acc: "0.55288
# 3: "train loss:"0.69140, "train acc: "0.54087
# 3: "train loss:"0.69462, "train acc: "0.52404
# 3: "train loss:"0.69120, "train acc: "0.53606
# 3: "train loss:"0.69446, "train acc: "0.53365
# 3: "train loss:"0.69190, "train acc: "0.53245
# 3: "train loss:"0.69057, "train acc: "0.53005
# 3: "train loss:"0.68954, "train acc: "0.54928
# 3: "train loss:"0.69240, "train acc: "0.54688
# 3: "train loss:"0.69370, "train acc: "0.53005
# 3: "train loss:"0.69169, "train acc: "0.53966
# 3: "train loss:"0.68925, "train acc: "0.55048
# 3: "train loss:"0.68895, "train acc: "0.54327
# 3: "train loss:"0.69388, "train acc: "0.54688
# 3: "train loss:"0.69794, "train acc: "0.53245
# 3: "train loss:"0.69395, "train acc: "0.53245
# 3: "train loss:"0.69773, "train acc: "0.53245
# 3: "train loss:"0.69191, "train acc: "0.53365
# 3: "train loss:"0.68894, "train acc: "0.55409
# 3: "train loss:"0.69357, "train acc: "0.52284
# 3: "train loss:"0.69386, "train acc: "0.53365
# 3: "train loss:"0.69175, "train acc: "0.54087
# 3: "train loss:"0.69204, "train acc: "0.53726
# 3: "train loss:"0.68941, "train acc: "0.54688
# 3: "train loss:"0.69203, "train acc: "0.53125
# 3: "train loss:"0.69035, "train acc: "0.53966
# 3: "train loss:"0.68624, "train acc: "0.55409
# 3: "val loss:"0.69393, "val acc: "0.53846
# 3: "val loss:"0.69027, "val acc: "0.55048
# 3: "val loss:"0.68858, "val acc: "0.53125
# 3: "val loss:"0.68887, "val acc: "0.54808
# 3: "val loss:"0.69231, "val acc: "0.52644
# 3: "val loss:"0.68906, "val acc: "0.54087
# 3: "val loss:"0.69253, "val acc: "0.54567
# 3: "val loss:"0.68678, "val acc: "0.56971
# 3: "val loss:"0.68975, "val acc: "0.53365
# 3: "val loss:"0.69448, "val acc: "0.51923
# 3: "val loss:"0.69346, "val acc: "0.54808
# 3: "val loss:"0.69990, "val acc: "0.51442
# 3: "val loss:"0.68882, "val acc: "0.56010
# 3: "val loss:"0.69126, "val acc: "0.54567
# 3: "val loss:"0.69108, "val acc: "0.52163
# 3: "val loss:"0.69508, "val acc: "0.53846
# 3: "val loss:"0.69423, "val acc: "0.51442
# 3: "val loss:"0.69023, "val acc: "0.54567
# 3: "val loss:"0.69386, "val acc: "0.53846
# 3: "val loss:"0.69205, "val acc: "0.53365
# 3: "val loss:"0.69589, "val acc: "0.52404
# 3: "val loss:"0.68905, "val acc: "0.54087
# 3: "val loss:"0.69511, "val acc: "0.51923
# 3: "val loss:"0.69208, "val acc: "0.53606
# 3: "val loss:"0.69032, "val acc: "0.54087
# 3: "val loss:"0.69385, "val acc: "0.51202
# 3: "val loss:"0.69062, "val acc: "0.54808
# 3: "val loss:"0.68886, "val acc: "0.52404
# 3: "val loss:"0.69148, "val acc: "0.55529
# 3: "val loss:"0.68799, "val acc: "0.55288
# 3: "val loss:"0.68874, "val acc: "0.54808
# 3: "val loss:"0.69015, "val acc: "0.54087
# 3: "val loss:"0.69349, "val acc: "0.51442
# 3: "val loss:"0.69304, "val acc: "0.52163
# 3: "val loss:"0.69197, "val acc: "0.52404
# 3: "val loss:"0.69059, "val acc: "0.53846
# 3: "val loss:"0.69123, "val acc: "0.54087
# 3: "val loss:"0.69141, "val acc: "0.55048
# 3: "val loss:"0.69263, "val acc: "0.54327
# 3: "val loss:"0.69558, "val acc: "0.52885
# 3: "val loss:"0.69435, "val acc: "0.54087
# 3: "val loss:"0.69596, "val acc: "0.52644
# 3: "val loss:"0.69809, "val acc: "0.53365
# 3: "val loss:"0.68768, "val acc: "0.53846
# 3: "val loss:"0.68706, "val acc: "0.54808
# 3: "val loss:"0.69625, "val acc: "0.50962
# 3: "val loss:"0.69690, "val acc: "0.50962
# 3: "val loss:"0.69166, "val acc: "0.54327
# 3: "val loss:"0.69113, "val acc: "0.54567
# 3: "val loss:"0.69352, "val acc: "0.55048
# 3: "val loss:"0.68809, "val acc: "0.55048
# 3: "val loss:"0.69138, "val acc: "0.52644
# 3: "val loss:"0.68877, "val acc: "0.53846
# 3: "val loss:"0.68605, "val acc: "0.54327
# 3: "val loss:"0.68830, "val acc: "0.54808
# 3: "val loss:"0.69050, "val acc: "0.54327
# 3: "val loss:"0.69538, "val acc: "0.51683
# 3: "val loss:"0.69244, "val acc: "0.54327
# 3: "val loss:"0.69338, "val acc: "0.54087
# 3: "val loss:"0.69571, "val acc: "0.52885
# 3: "val loss:"0.69666, "val acc: "0.51683
# 3: "val loss:"0.69023, "val acc: "0.55288
# 4: "train loss:"0.68403, "train acc: "0.56370
# 4: "train loss:"0.69585, "train acc: "0.52284
# 4: "train loss:"0.69121, "train acc: "0.53365
# 4: "train loss:"0.68957, "train acc: "0.54688
# 4: "train loss:"0.68660, "train acc: "0.55649
# 4: "train loss:"0.69236, "train acc: "0.52644
# 4: "train loss:"0.69065, "train acc: "0.53005
# 4: "train loss:"0.69102, "train acc: "0.53125
# 4: "train loss:"0.68866, "train acc: "0.54688
# 4: "train loss:"0.69332, "train acc: "0.53005
# 4: "train loss:"0.68793, "train acc: "0.55048
# 4: "train loss:"0.69134, "train acc: "0.53365
# 4: "train loss:"0.68996, "train acc: "0.54567
# 4: "train loss:"0.69202, "train acc: "0.53486
# 4: "train loss:"0.69055, "train acc: "0.54207
# 4: "train loss:"0.69301, "train acc: "0.53606
# 4: "train loss:"0.68784, "train acc: "0.54087
# 4: "train loss:"0.69366, "train acc: "0.54447
# 4: "train loss:"0.69240, "train acc: "0.53005
# 4: "train loss:"0.69047, "train acc: "0.53966
# 4: "train loss:"0.69353, "train acc: "0.54928
# 4: "train loss:"0.68816, "train acc: "0.54207
# 4: "train loss:"0.69188, "train acc: "0.53966
# 4: "train loss:"0.68980, "train acc: "0.53726
# 4: "train loss:"0.68787, "train acc: "0.53846
# 4: "train loss:"0.68795, "train acc: "0.54928
# 4: "train loss:"0.68893, "train acc: "0.54447
# 4: "train loss:"0.69035, "train acc: "0.53486
# 4: "train loss:"0.69193, "train acc: "0.53846
# 4: "train loss:"0.69257, "train acc: "0.53245
# 4: "train loss:"0.69694, "train acc: "0.52163
# 4: "train loss:"0.68989, "train acc: "0.54087
# 4: "train loss:"0.68767, "train acc: "0.53966
# 4: "train loss:"0.68959, "train acc: "0.55409
# 4: "train loss:"0.69276, "train acc: "0.53365
# 4: "train loss:"0.69175, "train acc: "0.53846
# 4: "train loss:"0.69593, "train acc: "0.51202
# 4: "train loss:"0.69239, "train acc: "0.53966
# 4: "train loss:"0.69289, "train acc: "0.53365
# 4: "train loss:"0.68965, "train acc: "0.53245
# 4: "train loss:"0.69140, "train acc: "0.53245
# 4: "train loss:"0.69252, "train acc: "0.53005
# 4: "train loss:"0.68758, "train acc: "0.55409
# 4: "train loss:"0.68597, "train acc: "0.57091
# 4: "train loss:"0.69018, "train acc: "0.54087
# 4: "train loss:"0.69099, "train acc: "0.53486
# 4: "train loss:"0.69219, "train acc: "0.53966
# 4: "train loss:"0.68863, "train acc: "0.55048
# 4: "train loss:"0.69128, "train acc: "0.53245
# 4: "train loss:"0.69184, "train acc: "0.53125
# 4: "train loss:"0.69216, "train acc: "0.53726
# 4: "train loss:"0.69025, "train acc: "0.54327
# 4: "train loss:"0.69262, "train acc: "0.53726
# 4: "train loss:"0.69099, "train acc: "0.53606
# 4: "train loss:"0.68986, "train acc: "0.54447
# 4: "train loss:"0.69062, "train acc: "0.53726
# 4: "train loss:"0.68875, "train acc: "0.54688
# 4: "train loss:"0.69010, "train acc: "0.53846
# 4: "train loss:"0.69085, "train acc: "0.54447
# 4: "train loss:"0.68562, "train acc: "0.55409
# 4: "train loss:"0.68543, "train acc: "0.55529
# 4: "train loss:"0.69093, "train acc: "0.54207
# 4: "train loss:"0.69275, "train acc: "0.53005
# 4: "train loss:"0.69152, "train acc: "0.55529
# 4: "train loss:"0.68754, "train acc: "0.54808
# 4: "train loss:"0.69069, "train acc: "0.53726
# 4: "train loss:"0.69003, "train acc: "0.53365
# 4: "train loss:"0.69165, "train acc: "0.54688
# 4: "train loss:"0.69038, "train acc: "0.53846
# 4: "train loss:"0.69045, "train acc: "0.54327
# 4: "train loss:"0.69118, "train acc: "0.53245
# 4: "train loss:"0.69412, "train acc: "0.53125
# 4: "train loss:"0.69116, "train acc: "0.53846
# 4: "train loss:"0.69252, "train acc: "0.52284
# 4: "train loss:"0.69385, "train acc: "0.52284
# 4: "train loss:"0.69178, "train acc: "0.54928
# 4: "train loss:"0.68770, "train acc: "0.55048
# 4: "train loss:"0.69442, "train acc: "0.53005
# 4: "train loss:"0.69233, "train acc: "0.54447
# 4: "train loss:"0.68766, "train acc: "0.54688
# 4: "train loss:"0.68861, "train acc: "0.54087
# 4: "train loss:"0.69457, "train acc: "0.53005
# 4: "train loss:"0.69122, "train acc: "0.53245
# 4: "train loss:"0.69105, "train acc: "0.53606
# 4: "train loss:"0.69128, "train acc: "0.53726
# 4: "train loss:"0.68995, "train acc: "0.54928
# 4: "train loss:"0.69473, "train acc: "0.52043
# 4: "train loss:"0.68921, "train acc: "0.54087
# 4: "train loss:"0.69170, "train acc: "0.53245
# 4: "train loss:"0.69197, "train acc: "0.53486
# 4: "train loss:"0.69114, "train acc: "0.55889
# 4: "train loss:"0.68979, "train acc: "0.54087
# 4: "train loss:"0.69068, "train acc: "0.54447
# 4: "train loss:"0.68735, "train acc: "0.54808
# 4: "train loss:"0.69233, "train acc: "0.53125
# 4: "train loss:"0.68788, "train acc: "0.54087
# 4: "train loss:"0.68847, "train acc: "0.55288
# 4: "train loss:"0.69051, "train acc: "0.55168
# 4: "train loss:"0.68852, "train acc: "0.55288
# 4: "train loss:"0.69097, "train acc: "0.54087
# 4: "train loss:"0.69540, "train acc: "0.52404
# 4: "train loss:"0.69172, "train acc: "0.53606
# 4: "train loss:"0.69356, "train acc: "0.53365
# 4: "train loss:"0.69302, "train acc: "0.53245
# 4: "train loss:"0.69068, "train acc: "0.53005
# 4: "train loss:"0.69093, "train acc: "0.54928
# 4: "train loss:"0.68936, "train acc: "0.54688
# 4: "train loss:"0.69401, "train acc: "0.53005
# 4: "train loss:"0.69102, "train acc: "0.53966
# 4: "train loss:"0.68801, "train acc: "0.55048
# 4: "train loss:"0.68918, "train acc: "0.54327
# 4: "train loss:"0.69437, "train acc: "0.54688
# 4: "train loss:"0.69545, "train acc: "0.53245
# 4: "train loss:"0.69414, "train acc: "0.53245
# 4: "train loss:"0.69385, "train acc: "0.53245
# 4: "train loss:"0.69116, "train acc: "0.53365
# 4: "train loss:"0.68966, "train acc: "0.55409
# 4: "train loss:"0.69419, "train acc: "0.52284
# 4: "train loss:"0.69412, "train acc: "0.53365
# 4: "train loss:"0.69120, "train acc: "0.54087
# 4: "train loss:"0.69293, "train acc: "0.53726
# 4: "train loss:"0.68923, "train acc: "0.54688
# 4: "train loss:"0.69138, "train acc: "0.53125
# 4: "train loss:"0.69136, "train acc: "0.53966
# 4: "train loss:"0.68483, "train acc: "0.55409
# 4: "val loss:"0.69334, "val acc: "0.53846
# 4: "val loss:"0.68738, "val acc: "0.55048
# 4: "val loss:"0.68707, "val acc: "0.53125
# 4: "val loss:"0.68834, "val acc: "0.54808
# 4: "val loss:"0.69031, "val acc: "0.52644
# 4: "val loss:"0.68970, "val acc: "0.54087
# 4: "val loss:"0.69370, "val acc: "0.54567
# 4: "val loss:"0.68795, "val acc: "0.56971
# 4: "val loss:"0.69213, "val acc: "0.53365
# 4: "val loss:"0.69518, "val acc: "0.51923
# 4: "val loss:"0.69145, "val acc: "0.54808
# 4: "val loss:"0.69977, "val acc: "0.51442
# 4: "val loss:"0.68933, "val acc: "0.56010
# 4: "val loss:"0.69215, "val acc: "0.54567
# 4: "val loss:"0.69414, "val acc: "0.52163
# 4: "val loss:"0.69549, "val acc: "0.53846
# 4: "val loss:"0.69496, "val acc: "0.51442
# 4: "val loss:"0.69143, "val acc: "0.54567
# 4: "val loss:"0.69568, "val acc: "0.53846
# 4: "val loss:"0.69414, "val acc: "0.53365
# 4: "val loss:"0.69770, "val acc: "0.52404
# 4: "val loss:"0.68996, "val acc: "0.54087
# 4: "val loss:"0.69437, "val acc: "0.51923
# 4: "val loss:"0.69400, "val acc: "0.53606
# 4: "val loss:"0.69021, "val acc: "0.54087
# 4: "val loss:"0.69357, "val acc: "0.51202
# 4: "val loss:"0.69198, "val acc: "0.54808
# 4: "val loss:"0.68835, "val acc: "0.52404
# 4: "val loss:"0.69104, "val acc: "0.55529
# 4: "val loss:"0.68836, "val acc: "0.55288
# 4: "val loss:"0.68928, "val acc: "0.54808
# 4: "val loss:"0.68930, "val acc: "0.54087
# 4: "val loss:"0.69343, "val acc: "0.51442
# 4: "val loss:"0.69382, "val acc: "0.52163
# 4: "val loss:"0.69329, "val acc: "0.52404
# 4: "val loss:"0.69278, "val acc: "0.53846
# 4: "val loss:"0.68931, "val acc: "0.54087
# 4: "val loss:"0.69156, "val acc: "0.55048
# 4: "val loss:"0.69460, "val acc: "0.54327
# 4: "val loss:"0.69237, "val acc: "0.52885
# 4: "val loss:"0.69389, "val acc: "0.54087
# 4: "val loss:"0.69618, "val acc: "0.52644
# 4: "val loss:"0.69616, "val acc: "0.53365
# 4: "val loss:"0.68972, "val acc: "0.53846
# 4: "val loss:"0.68853, "val acc: "0.54808
# 4: "val loss:"0.69595, "val acc: "0.50962
# 4: "val loss:"0.69933, "val acc: "0.50962
# 4: "val loss:"0.69130, "val acc: "0.54327
# 4: "val loss:"0.69329, "val acc: "0.54567
# 4: "val loss:"0.69334, "val acc: "0.55048
# 4: "val loss:"0.69194, "val acc: "0.55048
# 4: "val loss:"0.69250, "val acc: "0.52644
# 4: "val loss:"0.68789, "val acc: "0.53846
# 4: "val loss:"0.68343, "val acc: "0.54327
# 4: "val loss:"0.68897, "val acc: "0.54808
# 4: "val loss:"0.69156, "val acc: "0.54327
# 4: "val loss:"0.69810, "val acc: "0.51683
# 4: "val loss:"0.69351, "val acc: "0.54327
# 4: "val loss:"0.69301, "val acc: "0.54087
# 4: "val loss:"0.69507, "val acc: "0.52885
# 4: "val loss:"0.69682, "val acc: "0.51683
# 4: "val loss:"0.69134, "val acc: "0.55288
# 5: "train loss:"0.68461, "train acc: "0.56370
# 5: "train loss:"0.69577, "train acc: "0.52284
# 5: "train loss:"0.69017, "train acc: "0.53365
# 5: "train loss:"0.68991, "train acc: "0.54688
# 5: "train loss:"0.68829, "train acc: "0.55649
# 5: "train loss:"0.69188, "train acc: "0.52644
# 5: "train loss:"0.69004, "train acc: "0.53005
# 5: "train loss:"0.69138, "train acc: "0.53125
# 5: "train loss:"0.68886, "train acc: "0.54688
# 5: "train loss:"0.69241, "train acc: "0.53005
# 5: "train loss:"0.68662, "train acc: "0.55048
# 5: "train loss:"0.69122, "train acc: "0.53365
# 5: "train loss:"0.69065, "train acc: "0.54567
# 5: "train loss:"0.69188, "train acc: "0.53486
# 5: "train loss:"0.69184, "train acc: "0.54207
# 5: "train loss:"0.69225, "train acc: "0.53606
# 5: "train loss:"0.68740, "train acc: "0.54087
# 5: "train loss:"0.69175, "train acc: "0.54447
# 5: "train loss:"0.69214, "train acc: "0.53005
# 5: "train loss:"0.69029, "train acc: "0.53966
# 5: "train loss:"0.69255, "train acc: "0.54928
# 5: "train loss:"0.68889, "train acc: "0.54207
# 5: "train loss:"0.69136, "train acc: "0.53966
# 5: "train loss:"0.68978, "train acc: "0.53726
# 5: "train loss:"0.68771, "train acc: "0.53846
# 5: "train loss:"0.68874, "train acc: "0.54928
# 5: "train loss:"0.68906, "train acc: "0.54447
# 5: "train loss:"0.68960, "train acc: "0.53486
# 5: "train loss:"0.69274, "train acc: "0.53846
# 5: "train loss:"0.69219, "train acc: "0.53245
# 5: "train loss:"0.69464, "train acc: "0.52163
# 5: "train loss:"0.68967, "train acc: "0.54087
# 5: "train loss:"0.68873, "train acc: "0.53966
# 5: "train loss:"0.68835, "train acc: "0.55409
# 5: "train loss:"0.69209, "train acc: "0.53365
# 5: "train loss:"0.69084, "train acc: "0.53846
# 5: "train loss:"0.69633, "train acc: "0.51202
# 5: "train loss:"0.69136, "train acc: "0.53966
# 5: "train loss:"0.69334, "train acc: "0.53365
# 5: "train loss:"0.68978, "train acc: "0.53245
# 5: "train loss:"0.69165, "train acc: "0.53245
# 5: "train loss:"0.69065, "train acc: "0.53005
# 5: "train loss:"0.68763, "train acc: "0.55409
# 5: "train loss:"0.68567, "train acc: "0.57091
# 5: "train loss:"0.69048, "train acc: "0.54087
# 5: "train loss:"0.69122, "train acc: "0.53486
# 5: "train loss:"0.69128, "train acc: "0.53966
# 5: "train loss:"0.68792, "train acc: "0.55048
# 5: "train loss:"0.69047, "train acc: "0.53245
# 5: "train loss:"0.69189, "train acc: "0.53125
# 5: "train loss:"0.69045, "train acc: "0.53726
# 5: "train loss:"0.69208, "train acc: "0.54327
# 5: "train loss:"0.69120, "train acc: "0.53726
# 5: "train loss:"0.69241, "train acc: "0.53606
# 5: "train loss:"0.69000, "train acc: "0.54447
# 5: "train loss:"0.69126, "train acc: "0.53726
# 5: "train loss:"0.68751, "train acc: "0.54688
# 5: "train loss:"0.69064, "train acc: "0.53846
# 5: "train loss:"0.69027, "train acc: "0.54447
# 5: "train loss:"0.68638, "train acc: "0.55409
# 5: "train loss:"0.68529, "train acc: "0.55529
# 5: "train loss:"0.68962, "train acc: "0.54207
# 5: "train loss:"0.69259, "train acc: "0.53005
# 5: "train loss:"0.69153, "train acc: "0.55529
# 5: "train loss:"0.68865, "train acc: "0.54808
# 5: "train loss:"0.69144, "train acc: "0.53726
# 5: "train loss:"0.69051, "train acc: "0.53365
# 5: "train loss:"0.69304, "train acc: "0.54688
# 5: "train loss:"0.69023, "train acc: "0.53846
# 5: "train loss:"0.69023, "train acc: "0.54327
# 5: "train loss:"0.69196, "train acc: "0.53245
# 5: "train loss:"0.69309, "train acc: "0.53125
# 5: "train loss:"0.69076, "train acc: "0.53846
# 5: "train loss:"0.69170, "train acc: "0.52284
# 5: "train loss:"0.69473, "train acc: "0.52284
# 5: "train loss:"0.69041, "train acc: "0.54928
# 5: "train loss:"0.68740, "train acc: "0.55048
# 5: "train loss:"0.69375, "train acc: "0.53005
# 5: "train loss:"0.69334, "train acc: "0.54447
# 5: "train loss:"0.68947, "train acc: "0.54688
# 5: "train loss:"0.68863, "train acc: "0.54087
# 5: "train loss:"0.69350, "train acc: "0.53005
# 5: "train loss:"0.69099, "train acc: "0.53245
# 5: "train loss:"0.69121, "train acc: "0.53606
# 5: "train loss:"0.69004, "train acc: "0.53726
# 5: "train loss:"0.68779, "train acc: "0.54928
# 5: "train loss:"0.69544, "train acc: "0.52043
# 5: "train loss:"0.68951, "train acc: "0.54087
# 5: "train loss:"0.69177, "train acc: "0.53245
# 5: "train loss:"0.69187, "train acc: "0.53486
# 5: "train loss:"0.68914, "train acc: "0.55889
# 5: "train loss:"0.69041, "train acc: "0.54087
# 5: "train loss:"0.68978, "train acc: "0.54447
# 5: "train loss:"0.68930, "train acc: "0.54808
# 5: "train loss:"0.69286, "train acc: "0.53125
# 5: "train loss:"0.68955, "train acc: "0.54087
# 5: "train loss:"0.68759, "train acc: "0.55288
# 5: "train loss:"0.68822, "train acc: "0.55168
# 5: "train loss:"0.68817, "train acc: "0.55288
# 5: "train loss:"0.69114, "train acc: "0.54087
# 5: "train loss:"0.69443, "train acc: "0.52404
# 5: "train loss:"0.69070, "train acc: "0.53606
# 5: "train loss:"0.69304, "train acc: "0.53365
# 5: "train loss:"0.69272, "train acc: "0.53245
# 5: "train loss:"0.69212, "train acc: "0.53005
# 5: "train loss:"0.69127, "train acc: "0.54928
# 5: "train loss:"0.68891, "train acc: "0.54688
# 5: "train loss:"0.69198, "train acc: "0.53005
# 5: "train loss:"0.69089, "train acc: "0.53966
# 5: "train loss:"0.68782, "train acc: "0.55048
# 5: "train loss:"0.69007, "train acc: "0.54327
# 5: "train loss:"0.69305, "train acc: "0.54688
# 5: "train loss:"0.69523, "train acc: "0.53245
# 5: "train loss:"0.69075, "train acc: "0.53245
# 5: "train loss:"0.69549, "train acc: "0.53245
# 5: "train loss:"0.69273, "train acc: "0.53365
# 5: "train loss:"0.69007, "train acc: "0.55409
# 5: "train loss:"0.69394, "train acc: "0.52284
# 5: "train loss:"0.69214, "train acc: "0.53365
# 5: "train loss:"0.69082, "train acc: "0.54087
# 5: "train loss:"0.69259, "train acc: "0.53726
# 5: "train loss:"0.68821, "train acc: "0.54688
# 5: "train loss:"0.68992, "train acc: "0.53125
# 5: "train loss:"0.68910, "train acc: "0.53966
# 5: "train loss:"0.68648, "train acc: "0.55409
# ...
# 8: "train loss:"0.68968, "train acc: "0.54087
# 8: "train loss:"0.68944, "train acc: "0.54447
# 8: "train loss:"0.69141, "train acc: "0.53005
# 8: "train loss:"0.69023, "train acc: "0.53966
# 8: "train loss:"0.68865, "train acc: "0.54928
# 8: "train loss:"0.69003, "train acc: "0.54207
# 8: "train loss:"0.69053, "train acc: "0.53966
# 8: "train loss:"0.69074, "train acc: "0.53726
# 8: "train loss:"0.68910, "train acc: "0.53846
# 8: "train loss:"0.68851, "train acc: "0.54928
# 8: "train loss:"0.68892, "train acc: "0.54447
# 8: "train loss:"0.69064, "train acc: "0.53486
# 8: "train loss:"0.69004, "train acc: "0.53846
# 8: "train loss:"0.69241, "train acc: "0.53245
# 8: "train loss:"0.69361, "train acc: "0.52163
# 8: "train loss:"0.69001, "train acc: "0.54087
# 8: "train loss:"0.69037, "train acc: "0.53966
# 8: "train loss:"0.68835, "train acc: "0.55409
# 8: "train loss:"0.69171, "train acc: "0.53365
# 8: "train loss:"0.69163, "train acc: "0.53846
# 8: "train loss:"0.69444, "train acc: "0.51202
# 8: "train loss:"0.69034, "train acc: "0.53966
# 8: "train loss:"0.69096, "train acc: "0.53365
# 8: "train loss:"0.69026, "train acc: "0.53245
# 8: "train loss:"0.69218, "train acc: "0.53245
# 8: "train loss:"0.69113, "train acc: "0.53005
# 8: "train loss:"0.68701, "train acc: "0.55409
# 8: "train loss:"0.68576, "train acc: "0.57091
# 8: "train loss:"0.68922, "train acc: "0.54087
# 8: "train loss:"0.69097, "train acc: "0.53486
# 8: "train loss:"0.69008, "train acc: "0.53966
# 8: "train loss:"0.68787, "train acc: "0.55048
# 8: "train loss:"0.69130, "train acc: "0.53245
# 8: "train loss:"0.69130, "train acc: "0.53125
# 8: "train loss:"0.69078, "train acc: "0.53726
# 8: "train loss:"0.68984, "train acc: "0.54327
# 8: "train loss:"0.69075, "train acc: "0.53726
# 8: "train loss:"0.69048, "train acc: "0.53606
# 8: "train loss:"0.68926, "train acc: "0.54447
# 8: "train loss:"0.69034, "train acc: "0.53726
# 8: "train loss:"0.68885, "train acc: "0.54688
# 8: "train loss:"0.69055, "train acc: "0.53846
# 8: "train loss:"0.68921, "train acc: "0.54447
# 8: "train loss:"0.68828, "train acc: "0.55409
# 8: "train loss:"0.68760, "train acc: "0.55529
# 8: "train loss:"0.68974, "train acc: "0.54207
# 8: "train loss:"0.69253, "train acc: "0.53005
# 8: "train loss:"0.68738, "train acc: "0.55529
# 8: "train loss:"0.68852, "train acc: "0.54808
# 8: "train loss:"0.69016, "train acc: "0.53726
# 8: "train loss:"0.69115, "train acc: "0.53365
# 8: "train loss:"0.68928, "train acc: "0.54688
# 8: "train loss:"0.69075, "train acc: "0.53846
# 8: "train loss:"0.68926, "train acc: "0.54327
# 8: "train loss:"0.69094, "train acc: "0.53245
# 8: "train loss:"0.69221, "train acc: "0.53125
# 8: "train loss:"0.69125, "train acc: "0.53846
# 8: "train loss:"0.69233, "train acc: "0.52284
# 8: "train loss:"0.69353, "train acc: "0.52284
# 8: "train loss:"0.68965, "train acc: "0.54928
# 8: "train loss:"0.68851, "train acc: "0.55048
# 8: "train loss:"0.69187, "train acc: "0.53005
# 8: "train loss:"0.69002, "train acc: "0.54447
# 8: "train loss:"0.68878, "train acc: "0.54688
# 8: "train loss:"0.68987, "train acc: "0.54087
# 8: "train loss:"0.69177, "train acc: "0.53005
# 8: "train loss:"0.69094, "train acc: "0.53245
# 8: "train loss:"0.69102, "train acc: "0.53606
# 8: "train loss:"0.69004, "train acc: "0.53726
# 8: "train loss:"0.68884, "train acc: "0.54928
# 8: "train loss:"0.69283, "train acc: "0.52043
# 8: "train loss:"0.68877, "train acc: "0.54087
# 8: "train loss:"0.69151, "train acc: "0.53245
# 8: "train loss:"0.69067, "train acc: "0.53486
# 8: "train loss:"0.68754, "train acc: "0.55889
# 8: "train loss:"0.68943, "train acc: "0.54087
# 8: "train loss:"0.68824, "train acc: "0.54447
# 8: "train loss:"0.68799, "train acc: "0.54808
# 8: "train loss:"0.69205, "train acc: "0.53125
# 8: "train loss:"0.68989, "train acc: "0.54087
# 8: "train loss:"0.68722, "train acc: "0.55288
# 8: "train loss:"0.68806, "train acc: "0.55168
# 8: "train loss:"0.68803, "train acc: "0.55288
# 8: "train loss:"0.68988, "train acc: "0.54087
# 8: "train loss:"0.69308, "train acc: "0.52404
# 8: "train loss:"0.68928, "train acc: "0.53606
# 8: "train loss:"0.69009, "train acc: "0.53365
# 8: "train loss:"0.69117, "train acc: "0.53245
# 8: "train loss:"0.69079, "train acc: "0.53005
# 8: "train loss:"0.68873, "train acc: "0.54928
# 8: "train loss:"0.68909, "train acc: "0.54688
# 8: "train loss:"0.69076, "train acc: "0.53005
# 8: "train loss:"0.68975, "train acc: "0.53966
# 8: "train loss:"0.68864, "train acc: "0.55048
# 8: "train loss:"0.68955, "train acc: "0.54327
# 8: "train loss:"0.68973, "train acc: "0.54688
# 8: "train loss:"0.69239, "train acc: "0.53245
# 8: "train loss:"0.69123, "train acc: "0.53245
# 8: "train loss:"0.69146, "train acc: "0.53245
# 8: "train loss:"0.69098, "train acc: "0.53365
# 8: "train loss:"0.68763, "train acc: "0.55409
# 8: "train loss:"0.69231, "train acc: "0.52284
# 8: "train loss:"0.69119, "train acc: "0.53365
# 8: "train loss:"0.68982, "train acc: "0.54087
# 8: "train loss:"0.68975, "train acc: "0.53726
# 8: "train loss:"0.68919, "train acc: "0.54688
# 8: "train loss:"0.69136, "train acc: "0.53125
# 8: "train loss:"0.68970, "train acc: "0.53966
# 8: "train loss:"0.68844, "train acc: "0.55409
# 8: "val loss:"0.69055, "val acc: "0.53846
# 8: "val loss:"0.68969, "val acc: "0.55048
# 8: "val loss:"0.69147, "val acc: "0.53125
# 8: "val loss:"0.68976, "val acc: "0.54808
# 8: "val loss:"0.69238, "val acc: "0.52644
# 8: "val loss:"0.68943, "val acc: "0.54087
# 8: "val loss:"0.68896, "val acc: "0.54567
# 8: "val loss:"0.68532, "val acc: "0.56971
# 8: "val loss:"0.68892, "val acc: "0.53365
# 8: "val loss:"0.69342, "val acc: "0.51923
# 8: "val loss:"0.68975, "val acc: "0.54808
# 8: "val loss:"0.69471, "val acc: "0.51442
# 8: "val loss:"0.68737, "val acc: "0.56010
# 8: "val loss:"0.68949, "val acc: "0.54567
# 8: "val loss:"0.69142, "val acc: "0.52163
# 8: "val loss:"0.69062, "val acc: "0.53846
# 8: "val loss:"0.69370, "val acc: "0.51442
# 8: "val loss:"0.68838, "val acc: "0.54567
# 8: "val loss:"0.69195, "val acc: "0.53846
# 8: "val loss:"0.69113, "val acc: "0.53365
# 8: "val loss:"0.69138, "val acc: "0.52404
# 8: "val loss:"0.69039, "val acc: "0.54087
# 8: "val loss:"0.69295, "val acc: "0.51923
# 8: "val loss:"0.69110, "val acc: "0.53606
# 8: "val loss:"0.69100, "val acc: "0.54087
# 8: "val loss:"0.69535, "val acc: "0.51202
# 8: "val loss:"0.68912, "val acc: "0.54808
# 8: "val loss:"0.69314, "val acc: "0.52404
# 8: "val loss:"0.68794, "val acc: "0.55529
# 8: "val loss:"0.68736, "val acc: "0.55288
# 8: "val loss:"0.68796, "val acc: "0.54808
# 8: "val loss:"0.69049, "val acc: "0.54087
# 8: "val loss:"0.69450, "val acc: "0.51442
# 8: "val loss:"0.69270, "val acc: "0.52163
# 8: "val loss:"0.69263, "val acc: "0.52404
# 8: "val loss:"0.68954, "val acc: "0.53846
# 8: "val loss:"0.68961, "val acc: "0.54087
# 8: "val loss:"0.68784, "val acc: "0.55048
# 8: "val loss:"0.68850, "val acc: "0.54327
# 8: "val loss:"0.69263, "val acc: "0.52885
# 8: "val loss:"0.68925, "val acc: "0.54087
# 8: "val loss:"0.69200, "val acc: "0.52644
# 8: "val loss:"0.69106, "val acc: "0.53365
# 8: "val loss:"0.69153, "val acc: "0.53846
# 8: "val loss:"0.68818, "val acc: "0.54808
# 8: "val loss:"0.69551, "val acc: "0.50962
# 8: "val loss:"0.69436, "val acc: "0.50962
# 8: "val loss:"0.68959, "val acc: "0.54327
# 8: "val loss:"0.68872, "val acc: "0.54567
# 8: "val loss:"0.69024, "val acc: "0.55048
# 8: "val loss:"0.68913, "val acc: "0.55048
# 8: "val loss:"0.69135, "val acc: "0.52644
# 8: "val loss:"0.68947, "val acc: "0.53846
# 8: "val loss:"0.69011, "val acc: "0.54327
# 8: "val loss:"0.68829, "val acc: "0.54808
# 8: "val loss:"0.68810, "val acc: "0.54327
# 8: "val loss:"0.69256, "val acc: "0.51683
# 8: "val loss:"0.68956, "val acc: "0.54327
# 8: "val loss:"0.69039, "val acc: "0.54087
# 8: "val loss:"0.69106, "val acc: "0.52885
# 8: "val loss:"0.69475, "val acc: "0.51683
# 8: "val loss:"0.68817, "val acc: "0.55288
# 9: "train loss:"0.68575, "train acc: "0.56370
# 9: "train loss:"0.69245, "train acc: "0.52284
# 9: "train loss:"0.69096, "train acc: "0.53365
# 9: "train loss:"0.68928, "train acc: "0.54688
# 9: "train loss:"0.68718, "train acc: "0.55649
# 9: "train loss:"0.69246, "train acc: "0.52644
# 9: "train loss:"0.69119, "train acc: "0.53005
# 9: "train loss:"0.69101, "train acc: "0.53125
# 9: "train loss:"0.68867, "train acc: "0.54688
# 9: "train loss:"0.69118, "train acc: "0.53005
# 9: "train loss:"0.68865, "train acc: "0.55048
# 9: "train loss:"0.69102, "train acc: "0.53365
# 9: "train loss:"0.68895, "train acc: "0.54567
# 9: "train loss:"0.69049, "train acc: "0.53486
# 9: "train loss:"0.68938, "train acc: "0.54207
# 9: "train loss:"0.69042, "train acc: "0.53606
# 9: "train loss:"0.68939, "train acc: "0.54087
# 9: "train loss:"0.68932, "train acc: "0.54447
# 9: "train loss:"0.69169, "train acc: "0.53005
# 9: "train loss:"0.69014, "train acc: "0.53966
# 9: "train loss:"0.68830, "train acc: "0.54928
# 9: "train loss:"0.68935, "train acc: "0.54207
# 9: "train loss:"0.69022, "train acc: "0.53966
# 9: "train loss:"0.69062, "train acc: "0.53726
# 9: "train loss:"0.68962, "train acc: "0.53846
# 9: "train loss:"0.68845, "train acc: "0.54928
# 9: "train loss:"0.68925, "train acc: "0.54447
# 9: "train loss:"0.69080, "train acc: "0.53486
# 9: "train loss:"0.68984, "train acc: "0.53846
# 9: "train loss:"0.69182, "train acc: "0.53245
# 9: "train loss:"0.69331, "train acc: "0.52163
# 9: "train loss:"0.68964, "train acc: "0.54087
# 9: "train loss:"0.69027, "train acc: "0.53966
# 9: "train loss:"0.68827, "train acc: "0.55409
# 9: "train loss:"0.69131, "train acc: "0.53365
# 9: "train loss:"0.69097, "train acc: "0.53846
# 9: "train loss:"0.69448, "train acc: "0.51202
# 9: "train loss:"0.68966, "train acc: "0.53966
# 9: "train loss:"0.69061, "train acc: "0.53365
# 9: "train loss:"0.69088, "train acc: "0.53245
# 9: "train loss:"0.69152, "train acc: "0.53245
# 9: "train loss:"0.69129, "train acc: "0.53005
# 9: "train loss:"0.68735, "train acc: "0.55409
# 9: "train loss:"0.68572, "train acc: "0.57091
# 9: "train loss:"0.68963, "train acc: "0.54087
# 9: "train loss:"0.69109, "train acc: "0.53486
# 9: "train loss:"0.69004, "train acc: "0.53966
# 9: "train loss:"0.68790, "train acc: "0.55048
# 9: "train loss:"0.69124, "train acc: "0.53245
# 9: "train loss:"0.69117, "train acc: "0.53125
# 9: "train loss:"0.69079, "train acc: "0.53726
# 9: "train loss:"0.68976, "train acc: "0.54327
# 9: "train loss:"0.69048, "train acc: "0.53726
# 9: "train loss:"0.69071, "train acc: "0.53606
# 9: "train loss:"0.68933, "train acc: "0.54447
# 9: "train loss:"0.69023, "train acc: "0.53726
# 9: "train loss:"0.68855, "train acc: "0.54688
# 9: "train loss:"0.69026, "train acc: "0.53846
# 9: "train loss:"0.68897, "train acc: "0.54447
# 9: "train loss:"0.68816, "train acc: "0.55409
# 9: "train loss:"0.68746, "train acc: "0.55529
# 9: "train loss:"0.68951, "train acc: "0.54207
# 9: "train loss:"0.69197, "train acc: "0.53005
# 9: "train loss:"0.68723, "train acc: "0.55529
# 9: "train loss:"0.68879, "train acc: "0.54808
# 9: "train loss:"0.69017, "train acc: "0.53726
# 9: "train loss:"0.69084, "train acc: "0.53365
# 9: "train loss:"0.68903, "train acc: "0.54688
# 9: "train loss:"0.69048, "train acc: "0.53846
# 9: "train loss:"0.68964, "train acc: "0.54327
# 9: "train loss:"0.69132, "train acc: "0.53245
# 9: "train loss:"0.69188, "train acc: "0.53125
# 9: "train loss:"0.69051, "train acc: "0.53846
# 9: "train loss:"0.69229, "train acc: "0.52284
# 9: "train loss:"0.69291, "train acc: "0.52284
# 9: "train loss:"0.68888, "train acc: "0.54928
# 9: "train loss:"0.68842, "train acc: "0.55048
# 9: "train loss:"0.69163, "train acc: "0.53005
# 9: "train loss:"0.68965, "train acc: "0.54447
# 9: "train loss:"0.68906, "train acc: "0.54688
# 9: "train loss:"0.68970, "train acc: "0.54087
# 9: "train loss:"0.69165, "train acc: "0.53005
# 9: "train loss:"0.69130, "train acc: "0.53245
# 9: "train loss:"0.69089, "train acc: "0.53606
# 9: "train loss:"0.69020, "train acc: "0.53726
# 9: "train loss:"0.68887, "train acc: "0.54928
# 9: "train loss:"0.69251, "train acc: "0.52043
# 9: "train loss:"0.68912, "train acc: "0.54087
# 9: "train loss:"0.69126, "train acc: "0.53245
# 9: "train loss:"0.69056, "train acc: "0.53486
# 9: "train loss:"0.68777, "train acc: "0.55889
# 9: "train loss:"0.68964, "train acc: "0.54087
# 9: "train loss:"0.68846, "train acc: "0.54447
# 9: "train loss:"0.68884, "train acc: "0.54808
# 9: "train loss:"0.69179, "train acc: "0.53125
# 9: "train loss:"0.68985, "train acc: "0.54087
# 9: "train loss:"0.68731, "train acc: "0.55288
# 9: "train loss:"0.68779, "train acc: "0.55168
# 9: "train loss:"0.68780, "train acc: "0.55288
# 9: "train loss:"0.68964, "train acc: "0.54087
# 9: "train loss:"0.69259, "train acc: "0.52404
# 9: "train loss:"0.68973, "train acc: "0.53606
# 9: "train loss:"0.69051, "train acc: "0.53365
# 9: "train loss:"0.69160, "train acc: "0.53245
# 9: "train loss:"0.69073, "train acc: "0.53005
# 9: "train loss:"0.68886, "train acc: "0.54928
# 9: "train loss:"0.68876, "train acc: "0.54688
# 9: "train loss:"0.69197, "train acc: "0.53005
# 9: "train loss:"0.69014, "train acc: "0.53966
# 9: "train loss:"0.68819, "train acc: "0.55048
# 9: "train loss:"0.68934, "train acc: "0.54327
# 9: "train loss:"0.68924, "train acc: "0.54688
# 9: "train loss:"0.69195, "train acc: "0.53245
# 9: "train loss:"0.69126, "train acc: "0.53245
# 9: "train loss:"0.69167, "train acc: "0.53245
# 9: "train loss:"0.69117, "train acc: "0.53365
# 9: "train loss:"0.68768, "train acc: "0.55409
# 9: "train loss:"0.69310, "train acc: "0.52284
# 9: "train loss:"0.69133, "train acc: "0.53365
# 9: "train loss:"0.68972, "train acc: "0.54087
# 9: "train loss:"0.68972, "train acc: "0.53726
# 9: "train loss:"0.68892, "train acc: "0.54688
# 9: "train loss:"0.69133, "train acc: "0.53125
# 9: "train loss:"0.69000, "train acc: "0.53966
# 9: "train loss:"0.68872, "train acc: "0.55409
# 9: "val loss:"0.69024, "val acc: "0.53846
# 9: "val loss:"0.68964, "val acc: "0.55048
# 9: "val loss:"0.69149, "val acc: "0.53125
# 9: "val loss:"0.68968, "val acc: "0.54808
# 9: "val loss:"0.69215, "val acc: "0.52644
# 9: "val loss:"0.68896, "val acc: "0.54087
# 9: "val loss:"0.68894, "val acc: "0.54567
# 9: "val loss:"0.68492, "val acc: "0.56971
# 9: "val loss:"0.68938, "val acc: "0.53365
# 9: "val loss:"0.69275, "val acc: "0.51923
# 9: "val loss:"0.68938, "val acc: "0.54808
# 9: "val loss:"0.69416, "val acc: "0.51442
# 9: "val loss:"0.68793, "val acc: "0.56010
# 9: "val loss:"0.68970, "val acc: "0.54567
# 9: "val loss:"0.69177, "val acc: "0.52163
# 9: "val loss:"0.69084, "val acc: "0.53846
# 9: "val loss:"0.69392, "val acc: "0.51442
# 9: "val loss:"0.68815, "val acc: "0.54567
# 9: "val loss:"0.69143, "val acc: "0.53846
# 9: "val loss:"0.69068, "val acc: "0.53365
# 9: "val loss:"0.69088, "val acc: "0.52404
# 9: "val loss:"0.69153, "val acc: "0.54087
# 9: "val loss:"0.69281, "val acc: "0.51923
# 9: "val loss:"0.69051, "val acc: "0.53606
# 9: "val loss:"0.69022, "val acc: "0.54087
# 9: "val loss:"0.69544, "val acc: "0.51202
# 9: "val loss:"0.68866, "val acc: "0.54808
# 9: "val loss:"0.69273, "val acc: "0.52404
# 9: "val loss:"0.68774, "val acc: "0.55529
# 9: "val loss:"0.68729, "val acc: "0.55288
# 9: "val loss:"0.68907, "val acc: "0.54808
# 9: "val loss:"0.69048, "val acc: "0.54087
# 9: "val loss:"0.69438, "val acc: "0.51442
# 9: "val loss:"0.69270, "val acc: "0.52163
# 9: "val loss:"0.69274, "val acc: "0.52404
# 9: "val loss:"0.68967, "val acc: "0.53846
# 9: "val loss:"0.68892, "val acc: "0.54087
# 9: "val loss:"0.68782, "val acc: "0.55048
# 9: "val loss:"0.68840, "val acc: "0.54327
# 9: "val loss:"0.69159, "val acc: "0.52885
# 9: "val loss:"0.68948, "val acc: "0.54087
# 9: "val loss:"0.69136, "val acc: "0.52644
# 9: "val loss:"0.69142, "val acc: "0.53365
# 9: "val loss:"0.69083, "val acc: "0.53846
# 9: "val loss:"0.68868, "val acc: "0.54808
# 9: "val loss:"0.69503, "val acc: "0.50962
# 9: "val loss:"0.69454, "val acc: "0.50962
# 9: "val loss:"0.68966, "val acc: "0.54327
# 9: "val loss:"0.68951, "val acc: "0.54567
# 9: "val loss:"0.69012, "val acc: "0.55048
# 9: "val loss:"0.68875, "val acc: "0.55048
# 9: "val loss:"0.69140, "val acc: "0.52644
# 9: "val loss:"0.68959, "val acc: "0.53846
# 9: "val loss:"0.68957, "val acc: "0.54327
# 9: "val loss:"0.68802, "val acc: "0.54808
# 9: "val loss:"0.68900, "val acc: "0.54327
# 9: "val loss:"0.69309, "val acc: "0.51683
# 9: "val loss:"0.68967, "val acc: "0.54327
# 9: "val loss:"0.68924, "val acc: "0.54087
# 9: "val loss:"0.69133, "val acc: "0.52885
# 9: "val loss:"0.69296, "val acc: "0.51683
# 9: "val loss:"0.68742, "val acc: "0.55288

# %% [markdown]
# ## 5. 추론하기

# %%
submit = pd.read_csv('data/sample_submission.csv')

model.eval()
batch_size = test_loader.batch_size
batch_index = 0
for i, (images, targets) in enumerate(test_loader):
    images = images.to(device)
    targets = targets.to(device)
    outputs = model(images)
    outputs = outputs > 0.5
    batch_index = i * batch_size
    submit.iloc[batch_index:batch_index+batch_size, 1:] = \
        outputs.long().squeeze(0).detach().cpu().numpy()
    
submit.to_csv('submit.csv', index=False)

# %%
import matplotlib as plt

plt.plot(train_acc_list)
